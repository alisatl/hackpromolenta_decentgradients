# %%
! ls
# Out:
# AzureML		       catboost		lentahack		train_as_is.csv
# MMLSpark	       dana2_eda.ipynb	offers_date.csv		Плавильня.ipynb
# Nazar.ipynb	       dana_eda.ipynb	pytorch
# SparkML		       h2o		test_Offer_ID_map.json
# alisa-data-prep.ipynb  julia		test_as_is.csv

# %%
import json
import numpy as np

# %%
import os

import joblib
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.metrics import accuracy_score, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

# regression models
from sklearn.linear_model import LinearRegression
from lightgbm import LGBMRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor

# %%
from catboost import Pool, CatBoostRegressor

# %%
def load_dataset(path, is_test=False, y_col='UpLift'):
    df = pd.read_csv(path)
    if is_test: 
        return df
    return df[df.columns[:-1]], df[y_col]


def build_model(mdl):
    model = Pipeline([('onehot', OneHotEncoder(handle_unknown='ignore')), 
                      ("model", mdl)])
    return model


def tune_model():
    X_train, y_train = load_dataset(X_TRAIN, Y_TRAIN)
    model = build_model()

    gs = GridSearchCV(model, GRID_PARAMS, scoring="accuracy", n_jobs=-1, cv=5)
    gs.fit(X_train, y_train)

    print("Best Hyperparameters: {}".format(gs.best_params_))
    print("Best score: {:.2f}%".format(100 * gs.best_score_))


def train_model(print_params=False):
    X_train, y_train = load_dataset(PATH)

    model = build_model()
    model.set_params(**PARAMS)

    if print_params:
        print(model.get_params())

    model.fit(X_train, y_train)

    joblib.dump(model, MODEL_NAME)


def test_model():
    X_test, y_test = load_dataset(X_TEST, Y_TEST)
    model = joblib.load(MODEL_NAME)

    y_pred = model.predict(X_test)

    print("MAE on the test set: {:.2f}%".format(
        100 * mean_absolute_error(y_test, y_pred)))

# %%
num_attributes = housing_X.select_dtypes(exclude='object')
cat_attributes = housing_X.select_dtypes(include='object')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

def build_model2(mdl):
    global num_attribs
    global cat_attribs
    
    cat_pipeline = Pipeline([
     ('imputer', SimpleImputer(strategy='most_frequent')),
     ('onehot', OneHotEncoder(handle_unknown='ignore'))    
       ])
    num_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy="constant", fill_value=0)),
        ('std_scaler', StandardScaler()),
    ])
    
    preproc_pipeline = ColumnTransformer([
        ("num", num_pipeline, num_attribs),
        ("cat", cat_pipeline, cat_attribs),
    ])
        
    model = Pipeline([('preproc', preproc_pipeline), 
                      ("model", mdl)])
    return model

# %%
def build_model2(mdl, num_cols):
    
    num_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy="constant", fill_value=0)),
        ('std_scaler', StandardScaler()),
    ])
    
    model = Pipeline([('onehot', OneHotEncoder(handle_unknown='ignore')),
                      ColumnTransformer([("num", num_pipeline, num_cols)]), 
                      ("model", mdl)])
    return model

# %%
# submission prep 

def submission_prep(y_pred, offer_id_map_path, output_id):
    output_path = f'./data/submission{np.random.randint(1000, 2000)}.csv'   
    if  output_id: 
        output_path = f'./data/submission{output_id}.csv'
    Offer_IDs_test = json.load(open(offer_id_map_path, 'r'))
    sample_submission = pd.read_csv('./lentahack/20210521_sample_submission.csv')
    subm_offer_id_order = list(sample_submission['Offer_ID'])

    # check that we have correct Offer ID
    #set(subm_offer_id_order).difference(Offer_IDs_test)

    order_map = {k: v for v, k in enumerate(subm_offer_id_order)}

    submission = [None]*len(order_map)
    for offer_id, pred in zip(Offer_IDs_test, y_pred): 
        submission[order_map[offer_id]] = [offer_id, pred]

    print('Printing to', output_path)     
    with open(output_path, 'w') as fout: 
        print('Offer_ID,UpLift', file=fout)
        for o_id, y in submission: 
            print(f'{o_id},{y}', file=fout)

# %%
PATH = 'train_as_is.csv'
PATH_TEST = 'test_as_is.csv'
X_TRAIN, Y_TRAIN = load_dataset(PATH)
MODEL = LGBMRegressor()
GRID_PARAMS = _
PARAMS = _
MODEL_NAME = 'model_1'

# %%
X_tr, y_tr = load_dataset(PATH)

# %%
X_test = pd.read_csv('test_as_is.csv')

# %%
model = Pipeline([('onehot', OneHotEncoder(handle_unknown='ignore')), 
                  ("model", MODEL) 
                  ])

# %%
model.fit(X_tr, y_tr)
# Out:
# Pipeline(steps=[('onehot', OneHotEncoder(handle_unknown='ignore')),
#                 ('model', LGBMRegressor())])

# %%
# checking right on the Training set 
y_pred =  model.predict(X_tr)
mean_absolute_error(y_tr, y_pred)
# Out:
# 3.397615029802757

# %%
y_pred = model.predict(X_test)

# %%
len(y_pred), y_pred[:10]
# Out:
# (149,
#  array([ 3.40316398,  5.35092376,  7.51223333, 10.14554485,  3.63715244,
#          6.10871633,  7.56703453,  9.08632804, 10.60949484,  5.35092376]))

# %% [markdown]
# ## 1. Feat Set: Category Counts

# %%
# !ls data
# Out:
# test_Offer_ID_map_category_ct.json  test_category_ct.csv  train_category_ct.csv

# %%
PATH_TR = './data/train_category_ct.csv'
PATH_TEST = './data/test_category_ct.csv'
X_all = pd.read_csv(PATH_TR)
X_tr_orig, y_tr_orig = load_dataset(PATH_TR)
X_test = load_dataset(PATH_TEST, True)

X_train, X_val, y_train, y_val = train_test_split(X_tr_orig, y_tr_orig, test_size=0.2)

MODEL = LGBMRegressor()
GRID_PARAMS = _
PARAMS = _
MODEL_NAME = 'model_LGBMRegressor'

# %% [markdown]
# ## 2. Feat Set: Other Offers

# %%
# !ls data
# Out:
# off_to_skus_map.json	      submission5.csv
# offers_df_agg.csv	      submission6.csv
# offers_df_agg.json	      test_Offer_ID_map_category_ct.json
# offers_df_agg_sales_feat.csv  test_category_ct.csv
# submission1.csv		      test_other_ofrs.csv
# submission1hr.csv	      test_sales_feats.csv
# submission2.csv		      train_category_ct.csv
# submission3.csv		      train_other_ofrs.csv
# submission4.csv		      train_sales_feats.csv

# %% [markdown]
# ## 3 Feat Set: Sales Nums

# %%
PATH_TR = './data/train_sales_feats.csv'
PATH_TEST = './data/test_sales_feats.csv'
X_all = pd.read_csv(PATH_TR)
X_tr_orig, y_tr_orig = load_dataset(PATH_TR)
X_test = load_dataset(PATH_TEST, True)

# %%
cols_to_exclude = ['num_other_promos', 'num_skus_in_other_promos']
X_tr_orig = X_tr_orig.drop(cols_to_exclude, axis=1)
X_test = X_test.drop(cols_to_exclude, axis=1)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_tr_orig, y_tr_orig, test_size=0.2)

# %% [markdown]
# ## 4 Feat Set: Sales Nums w Diff

# %%
ls data
# Out:
# off_to_skus_map.json                 submission6.csv
# offers_df_agg.csv                    test_Offer_ID_map_category_ct.json
# offers_df_agg.json                   test_category_ct.csv
# offers_df_agg_sales_feat.csv         test_other_ofrs.csv
# offers_df_agg_sales_feat_w_diff.csv  test_sales_feats.csv
# submission1.csv                      test_sales_feats_w_diff.csv
# submission1hr.csv                    train_category_ct.csv
# submission2.csv                      train_other_ofrs.csv
# submission3.csv                      train_sales_feats.csv
# submission4.csv                      train_sales_feats_w_diff.csv
# submission5.csv

# %%
PATH_TR = './data/train_sales_feats_w_diff.csv'
PATH_TEST = './data/test_sales_feats_w_diff.csv'
X_all = pd.read_csv(PATH_TR)
X_tr_orig, y_tr_orig = load_dataset(PATH_TR)

# %%
X_tr_orig.drop(['pred_start_date', 'pred_end_date'], inplace=True, axis=1)

# %%
X_test = load_dataset(PATH_TEST, True)
X_test.drop(['pred_start_date', 'pred_end_date'], inplace=True, axis=1)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_tr_orig, y_tr_orig, test_size=0.2)

# %%
num_cols = X_train.columns[-15:]

# %%
cols_to_exclude = ['num_other_promos', 'num_skus_in_other_promos']


X_tr_orig = X_tr_orig.drop(cols_to_exclude, axis=1)
X_test = X_test.drop(cols_to_exclude, axis=1)

# %% [markdown]
# ## Model Zoo

# %%
regressors = [LGBMRegressor(), GradientBoostingRegressor(), AdaBoostRegressor(), XGBRegressor(), Lasso(), Ridge(), 
             CatBoostRegressor(silent=True)]

# %%
model0 = build_model(LGBMRegressor())
model1 = build_model(GradientBoostingRegressor()) 
model2 = build_model(AdaBoostRegressor()) 
model3 = build_model(XGBRegressor()) 
model4 = build_model(Lasso()) 
model5 = build_model(CatBoostRegressor(silent=True))

# %%
models = [model0, model1, model2, model3, model4, model5]

# %%
scaler = StandardScaler()

# %%
# validation 
for m in [model0, model1, model3, model5]: 
    m.fit(X_train, y_train)
    y_pred_val = m.predict(X_val)
    y_pred_tr = m.predict(X_train)
    print(m["model"])
    print(mean_absolute_error(y_val, y_pred_val), mean_absolute_error(y_train, y_pred_tr))
# Out:
# LGBMRegressor()
# 3.9571454947326212 2.517985898171956
# GradientBoostingRegressor()
# 4.1053911447005556 2.6183487513269044
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=48, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)
# 3.8755670332782994 0.912776474861224
# <catboost.core.CatBoostRegressor object at 0x7f78d6889e50>
# 3.8257309888659323 1.9794538236604111

# %%
model5.fit(X_tr_orig, y_tr_orig)
y_pred = model5.predict(X_test)

submission_prep(y_pred, './data/test_Offer_ID_map_category_ct.json', '_diff')
# Out:
# Printing to ./data/submission_diff.csv

# %%
#model1.fit(X_tr_orig, y_tr_orig)
y_pred = model1.predict(X_test)

submission_prep(y_pred, './data/test_Offer_ID_map_category_ct.json', '_diffm1')
# Out:
# Printing to ./data/submission_diffm1.csv

# %% [markdown]
# ### Model Zoo w/ Scaler

# %%
# %who
# Out:
# AdaBoostRegressor	 CatBoostRegressor	 ColumnTransformer	 DecisionTreeRegressor	 ElasticNet	 GRID_PARAMS	 GradientBoostingRegressor	 GridSearchCV	 KNeighborsRegressor
# LGBMRegressor	 Lasso	 LinearRegression	 MODEL	 MODEL_NAME	 OneHotEncoder	 PARAMS	 PATH	 PATH_TEST
# PATH_TR	 Pipeline	 Pool	 RandomForestRegressor	 Ridge	 SVR	 SimpleImputer	 StandardScaler	 XGBRegressor
# X_TRAIN	 X_all	 X_test	 X_test_	 X_tr_orig	 X_tr_orig_	 X_train	 X_train_	 X_val
# X_val_	 Y_TRAIN	 accuracy_score	 build_model	 build_model2	 cat_attribs	 cat_attributes	 cols_to_exclude	 joblib
# json	 load_dataset	 m	 mean_absolute_error	 model0	 model1	 model2	 model3	 model4
# model5	 models	 models2	 np	 num_attribs	 num_attributes	 num_cols	 os	 pd
# regressors	 submission_prep	 test_model	 train_model	 train_test_split	 tune_model	 y_pred	 y_pred_tr	 y_pred_val
# y_tr_orig	 y_train	 y_train_	 y_val	 y_val_

# %%
X_train.shape
# Out:
# (592, 2627)

# %%
numerical_cols = X_train.select_dtypes(exclude = ['object']).columns
categorical_cols = X_train.select_dtypes(include = ['object'] ).columns
len(numerical_cols) + len(categorical_cols)
# Out:
# 2627

# %%
categorical_cols
# Out:
# Index(['Promo_type', 'start_date', 'end_date', 'duration'], dtype='object')

# %%
def build_model22(mdl, num_cols, cat_cols):
    
    
    num_transformer = Pipeline([
        ('imputer', SimpleImputer(strategy="constant", fill_value=0)),
        ('std_scaler', StandardScaler()),
    ])

    
    categorical_transformer_simple = Pipeline(steps=[
    ('imputer', SimpleImputer(missing_values=np.nan,strategy = 'most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))   
     ])
    
    data_transformer_simple = ColumnTransformer(
            transformers=[
                ('num', num_transformer, num_cols),
                ('cat', categorical_transformer_simple, cat_cols)
            ])
    
    model = Pipeline([
                      ('preproc', data_transformer_simple),  
                      #('onehot', OneHotEncoder(handle_unknown='ignore')),   
                      ("model", mdl)])
    return model

# %%
numerical_cols = X_train.select_dtypes(exclude = ['object']).columns
categorical_cols = X_train.select_dtypes(include = ['object'] ).columns

categorical_cols, len(numerical_cols) + len(categorical_cols)
# Out:
# (Index(['Promo_type', 'start_date', 'end_date', 'duration'], dtype='object'),
#  2627)

# %%
m = build_model22(LGBMRegressor(), numerical_cols, categorical_cols)

# %%
m.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preproc',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=0,
#                                                                                  strategy='constant')),
#                                                                   ('std_scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['num_skus', 'num_hl1', 'num_hl2', 'num_hl3', 'num_hl4', 'hl_1_0',
#        'hl_1_1', 'hl_2_0', 'hl_2_1', 'hl_2_2',
#        ...
#        'avg_min_suppl_pred', 'avg_mean_sales_pred', 'avg_max_sales_pred',
#        'avg...vg_sls',
#        'diff_min_avg_nums', 'diff_max_avg_nums', 'diff_min_avg_suppl',
#        'diff_max_avg_suppl'],
#       dtype='object', length=2623)),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   Index(['Promo_type', 'start_date', 'end_date', 'duration'], dtype='object'))])),
#                 ('model', LGBMRegressor())])

# %%
models22 = [build_model22(r, numerical_cols, categorical_cols) for r in regressors]
len(models22)
# Out:
# 7

# %%
# validation 
for m in models22: 
    m.fit(X_train, y_train)
    y_pred_val = m.predict(X_val)
    y_pred_tr = m.predict(X_train)
    print(m["model"])
    print(mean_absolute_error(y_val, y_pred_val), mean_absolute_error(y_train, y_pred_tr))
# Out:
# LGBMRegressor()
# 3.743611086050003 1.4077008952577343
# GradientBoostingRegressor()
# 3.894492419917168 2.1840407505706505
# AdaBoostRegressor()
# 4.825455368892371 4.484143181350597
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=48, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)
# 3.5440416968676907 0.5735012002660322
# Lasso()
# 4.520680638873011 4.553849519984007
# Ridge()
# 5.147343451436054 1.8567322668264303
# <catboost.core.CatBoostRegressor object at 0x7f78d62369d0>
# 3.649157701229511 1.5364111600068453

# %%
models22[6]["model"]

# %%
models22[3].fit(X_tr_orig, y_tr_orig)
y_pred = models22[3].predict(X_test)
submission_prep(y_pred, './data/test_Offer_ID_map_category_ct.json', 14)
# Out:
# Printing to ./data/submission14.csv

# %%
models22[6].fit(X_tr_orig, y_tr_orig)
y_pred = models22[6].predict(X_test)
submission_prep(y_pred, './data/test_Offer_ID_map_category_ct.json', 13)
# Out:
# Printing to ./data/submission13.csv

# %%
models2 = [build_model22(r, num_cols) for r in regressors]

# %%
models2[0]["model"]
# Out:
# LGBMRegressor()

# %%
StandardScaler?

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
# validation 
for m in models2[:1]: 
    m.fit(X_train, y_train)
    y_pred_val = m.predict(X_val)
    y_pred_tr = m.predict(X_train)
    print(m["model"])
    print(mean_absolute_error(y_val, y_pred_val), mean_absolute_error(y_train, y_pred_tr))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /anaconda/envs/py38_default/lib/python3.8/site-packages/sklearn/utils/__init__.py in _get_column_indices(X, key)
#     373         try:
# --> 374             all_columns = X.columns
#     375         except AttributeError:
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/scipy/sparse/base.py in __getattr__(self, attr)
#     686         else:
# --> 687             raise AttributeError(attr + " not found")
#     688
#
# AttributeError: columns not found
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-9f78df775085> in <module>
#       1 # validation
#       2 for m in models2[:1]:
# ----> 3     m.fit(X_train, y_train)
#       4     y_pred_val = m.predict(X_val)
#       5     y_pred_tr = m.predict(X_train)
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     339         """
#     340         fit_params_steps = self._check_fit_params(**fit_params)
# --> 341         Xt = self._fit(X, y, **fit_params_steps)
#     342         with _print_elapsed_time('Pipeline',
#     343                                  self._log_message(len(self.steps) - 1)):
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params_steps)
#     301                 cloned_transformer = clone(transformer)
#     302             # Fit or load from cache the current transformer
# --> 303             X, fitted_transformer = fit_transform_one_cached(
#     304                 cloned_transformer, X, y, None,
#     305                 message_clsname='Pipeline',
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     350
#     351     def __call__(self, *args, **kwargs):
# --> 352         return self.func(*args, **kwargs)
#     353
#     354     def call_and_shelve(self, *args, **kwargs):
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     752     with _print_elapsed_time(message_clsname, message):
#     753         if hasattr(transformer, 'fit_transform'):
# --> 754             res = transformer.fit_transform(X, y, **fit_params)
#     755         else:
#     756             res = transformer.fit(X, y, **fit_params).transform(X)
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/sklearn/compose/_column_transformer.py in fit_transform(self, X, y)
#     504         self._validate_transformers()
#     505         self._validate_column_callables(X)
# --> 506         self._validate_remainder(X)
#     507
#     508         result = self._fit_transform(X, y, _fit_transform_one)
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/sklearn/compose/_column_transformer.py in _validate_remainder(self, X)
#     330         cols = []
#     331         for columns in self._columns:
# --> 332             cols.extend(_get_column_indices(X, columns))
#     333
#     334         remaining_idx = sorted(set(range(self._n_features)) - set(cols))
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/sklearn/utils/__init__.py in _get_column_indices(X, key)
#     374             all_columns = X.columns
#     375         except AttributeError:
# --> 376             raise ValueError("Specifying the columns using strings is only "
#     377                              "supported for pandas DataFrames")
#     378         if isinstance(key, str):
#
# ValueError: Specifying the columns using strings is only supported for pandas DataFrames

# %% [markdown]
# ##### Comparing w/o Offer cols

# %%
cols_to_exclude = ['num_other_promos', 'num_skus_in_other_promos']
X_tr_orig_ = X_tr_orig.drop(cols_to_exclude, axis=1)
X_test_ = X_test.drop(cols_to_exclude, axis=1)
X_train_, X_val_, y_train_, y_val_ = train_test_split(X_tr_orig_, y_tr_orig, test_size=0.2)

# %%
# validation 
for m in [model0, model1, model3, model5]: 
    m.fit(X_train_, y_train)
    y_pred_val = m.predict(X_val_)
    y_pred_tr = m.predict(X_train_)
    print(m["model"])
    print(mean_absolute_error(y_val, y_pred_val), mean_absolute_error(y_train, y_pred_tr))
# Out:
# LGBMRegressor()
# 4.679130404095676 3.63190277161753
# GradientBoostingRegressor()
# 4.390980488565595 3.8180816025355515
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=48, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)
# 4.587960878332384 2.0423967630515962
# <catboost.core.CatBoostRegressor object at 0x7f78d623a1c0>
# 4.462837288619407 3.187734691125384

# %%
model5.fit(X_tr_orig, y_tr_orig)
y_pred = model5.predict(X_test)

submission_prep(y_pred, './data/test_Offer_ID_map_category_ct.json', 6)
# Out:
# Printing to ./data/submission3.csv

# %%
model5 = build_model(CatBoostRegressor())

# %%
# 3.811659175054392 2.3031921382709273
for m in [model5]:
    m.fit(X_train, y_train)
    y_pred_val = m.predict(X_val)
    y_pred_tr = m.predict(X_train)
    print(m["model"])
    print(mean_absolute_error(y_val, y_pred_val), mean_absolute_error(y_train, y_pred_tr))
# Out:
# 0:	learn: 6.1758624	total: 92.5ms	remaining: 1m 32s
# 1:	learn: 6.1576197	total: 113ms	remaining: 56.4s
# 2:	learn: 6.1328365	total: 131ms	remaining: 43.5s
# 3:	learn: 6.1108295	total: 149ms	remaining: 37.2s
# 4:	learn: 6.0920717	total: 167ms	remaining: 33.1s
# 5:	learn: 6.0624676	total: 185ms	remaining: 30.7s
# 6:	learn: 6.0372404	total: 215ms	remaining: 30.5s
# 7:	learn: 6.0147230	total: 234ms	remaining: 29s
# 8:	learn: 5.9790275	total: 255ms	remaining: 28.1s
# 9:	learn: 5.9542382	total: 273ms	remaining: 27.1s
# 10:	learn: 5.9244557	total: 294ms	remaining: 26.4s
# 11:	learn: 5.9078697	total: 313ms	remaining: 25.8s
# 12:	learn: 5.8822876	total: 332ms	remaining: 25.2s
# 13:	learn: 5.8557884	total: 354ms	remaining: 24.9s
# 14:	learn: 5.8324648	total: 373ms	remaining: 24.5s
# 15:	learn: 5.8146196	total: 395ms	remaining: 24.3s
# 16:	learn: 5.8049613	total: 408ms	remaining: 23.6s
# 17:	learn: 5.7908378	total: 426ms	remaining: 23.2s
# 18:	learn: 5.7776997	total: 444ms	remaining: 22.9s
# 19:	learn: 5.7605040	total: 462ms	remaining: 22.6s
# 20:	learn: 5.7417678	total: 480ms	remaining: 22.4s
# 21:	learn: 5.7243381	total: 501ms	remaining: 22.3s
# 22:	learn: 5.7049807	total: 519ms	remaining: 22s
# 23:	learn: 5.6932222	total: 538ms	remaining: 21.9s
# 24:	learn: 5.6842465	total: 557ms	remaining: 21.7s
# 25:	learn: 5.6704831	total: 576ms	remaining: 21.6s
# 26:	learn: 5.6525254	total: 595ms	remaining: 21.5s
# 27:	learn: 5.6384890	total: 614ms	remaining: 21.3s
# 28:	learn: 5.6270869	total: 633ms	remaining: 21.2s
# 29:	learn: 5.6188345	total: 652ms	remaining: 21.1s
# 30:	learn: 5.6129074	total: 665ms	remaining: 20.8s
# 31:	learn: 5.5980840	total: 686ms	remaining: 20.7s
# 32:	learn: 5.5867300	total: 704ms	remaining: 20.6s
# 33:	learn: 5.5834352	total: 723ms	remaining: 20.6s
# 34:	learn: 5.5639955	total: 741ms	remaining: 20.4s
# 35:	learn: 5.5605230	total: 763ms	remaining: 20.4s
# 36:	learn: 5.5481799	total: 782ms	remaining: 20.3s
# 37:	learn: 5.5383957	total: 800ms	remaining: 20.3s
# 38:	learn: 5.5321708	total: 820ms	remaining: 20.2s
# 39:	learn: 5.5190449	total: 838ms	remaining: 20.1s
# 40:	learn: 5.5064710	total: 856ms	remaining: 20s
# 41:	learn: 5.5036916	total: 876ms	remaining: 20s
# 42:	learn: 5.4954532	total: 895ms	remaining: 19.9s
# 43:	learn: 5.4899640	total: 915ms	remaining: 19.9s
# 44:	learn: 5.4817792	total: 934ms	remaining: 19.8s
# 45:	learn: 5.4757699	total: 953ms	remaining: 19.8s
# 46:	learn: 5.4725469	total: 972ms	remaining: 19.7s
# 47:	learn: 5.4646877	total: 991ms	remaining: 19.7s
# 48:	learn: 5.4536935	total: 1.01s	remaining: 19.6s
# 49:	learn: 5.4469244	total: 1.03s	remaining: 19.6s
# 50:	learn: 5.4403861	total: 1.05s	remaining: 19.5s
# 51:	learn: 5.4323232	total: 1.07s	remaining: 19.4s
# 52:	learn: 5.4269750	total: 1.09s	remaining: 19.5s
# 53:	learn: 5.4181113	total: 1.11s	remaining: 19.4s
# 54:	learn: 5.4117211	total: 1.13s	remaining: 19.4s
# 55:	learn: 5.4082092	total: 1.15s	remaining: 19.3s
# 56:	learn: 5.4018025	total: 1.17s	remaining: 19.3s
# 57:	learn: 5.3993881	total: 1.18s	remaining: 19.2s
# 58:	learn: 5.3935116	total: 1.2s	remaining: 19.2s
# 59:	learn: 5.3897368	total: 1.22s	remaining: 19.1s
# 60:	learn: 5.3837457	total: 1.24s	remaining: 19.1s
# 61:	learn: 5.3760022	total: 1.26s	remaining: 19s
# 62:	learn: 5.3725476	total: 1.27s	remaining: 19s
# 63:	learn: 5.3686191	total: 1.29s	remaining: 18.9s
# 64:	learn: 5.3626769	total: 1.31s	remaining: 18.9s
# 65:	learn: 5.3550036	total: 1.33s	remaining: 18.8s
# 66:	learn: 5.3510778	total: 1.35s	remaining: 18.8s
# 67:	learn: 5.3437154	total: 1.37s	remaining: 18.8s
# 68:	learn: 5.3409457	total: 1.39s	remaining: 18.7s
# 69:	learn: 5.3298906	total: 1.4s	remaining: 18.6s
# 70:	learn: 5.3205574	total: 1.42s	remaining: 18.6s
# 71:	learn: 5.3142210	total: 1.44s	remaining: 18.6s
# 72:	learn: 5.3121384	total: 1.47s	remaining: 18.7s
# 73:	learn: 5.3085837	total: 1.5s	remaining: 18.8s
# 74:	learn: 5.3058864	total: 1.52s	remaining: 18.8s
# 75:	learn: 5.3026008	total: 1.54s	remaining: 18.8s
# 76:	learn: 5.2942784	total: 1.57s	remaining: 18.8s
# 77:	learn: 5.2894688	total: 1.58s	remaining: 18.7s
# 78:	learn: 5.2814396	total: 1.6s	remaining: 18.7s
# 79:	learn: 5.2770125	total: 1.62s	remaining: 18.7s
# 80:	learn: 5.2741955	total: 1.64s	remaining: 18.6s
# 81:	learn: 5.2706759	total: 1.66s	remaining: 18.6s
# 82:	learn: 5.2673497	total: 1.68s	remaining: 18.6s
# 83:	learn: 5.2657065	total: 1.7s	remaining: 18.6s
# 84:	learn: 5.2628871	total: 1.73s	remaining: 18.6s
# 85:	learn: 5.2599471	total: 1.75s	remaining: 18.6s
# 86:	learn: 5.2565933	total: 1.77s	remaining: 18.6s
# 87:	learn: 5.2522718	total: 1.79s	remaining: 18.5s
# 88:	learn: 5.2487519	total: 1.81s	remaining: 18.5s
# 89:	learn: 5.2460054	total: 1.82s	remaining: 18.4s
# 90:	learn: 5.2415149	total: 1.84s	remaining: 18.4s
# 91:	learn: 5.2391245	total: 1.86s	remaining: 18.4s
# 92:	learn: 5.2361904	total: 1.88s	remaining: 18.3s
# 93:	learn: 5.2327303	total: 1.9s	remaining: 18.3s
# 94:	learn: 5.2263344	total: 1.92s	remaining: 18.3s
# 95:	learn: 5.2245530	total: 1.93s	remaining: 18.2s
# 96:	learn: 5.2166265	total: 1.95s	remaining: 18.2s
# 97:	learn: 5.2138406	total: 1.97s	remaining: 18.2s
# 98:	learn: 5.2112527	total: 1.99s	remaining: 18.1s
# 99:	learn: 5.2091244	total: 2.01s	remaining: 18.1s
# 100:	learn: 5.2032917	total: 2.03s	remaining: 18s
# 101:	learn: 5.2007628	total: 2.05s	remaining: 18s
# 102:	learn: 5.1929565	total: 2.06s	remaining: 18s
# 103:	learn: 5.1899226	total: 2.08s	remaining: 17.9s
# 104:	learn: 5.1853262	total: 2.1s	remaining: 17.9s
# 105:	learn: 5.1799639	total: 2.12s	remaining: 17.9s
# 106:	learn: 5.1713124	total: 2.14s	remaining: 17.9s
# 107:	learn: 5.1688037	total: 2.16s	remaining: 17.9s
# 108:	learn: 5.1662099	total: 2.18s	remaining: 17.8s
# 109:	learn: 5.1627672	total: 2.2s	remaining: 17.8s
# 110:	learn: 5.1603039	total: 2.22s	remaining: 17.8s
# 111:	learn: 5.1577248	total: 2.23s	remaining: 17.7s
# 112:	learn: 5.1509984	total: 2.25s	remaining: 17.7s
# 113:	learn: 5.1469804	total: 2.27s	remaining: 17.6s
# 114:	learn: 5.1451810	total: 2.29s	remaining: 17.6s
# 115:	learn: 5.1421637	total: 2.3s	remaining: 17.6s
# 116:	learn: 5.1376445	total: 2.32s	remaining: 17.5s
# 117:	learn: 5.1350477	total: 2.34s	remaining: 17.5s
# 118:	learn: 5.1294297	total: 2.36s	remaining: 17.5s
# 119:	learn: 5.1261061	total: 2.37s	remaining: 17.4s
# 120:	learn: 5.1238353	total: 2.39s	remaining: 17.4s
# 121:	learn: 5.1223842	total: 2.41s	remaining: 17.4s
# 122:	learn: 5.1164946	total: 2.43s	remaining: 17.3s
# 123:	learn: 5.1117739	total: 2.45s	remaining: 17.3s
# 124:	learn: 5.1063788	total: 2.47s	remaining: 17.3s
# 125:	learn: 5.1030950	total: 2.49s	remaining: 17.2s
# 126:	learn: 5.1009484	total: 2.5s	remaining: 17.2s
# 127:	learn: 5.0984214	total: 2.52s	remaining: 17.2s
# 128:	learn: 5.0927522	total: 2.54s	remaining: 17.1s
# 129:	learn: 5.0913879	total: 2.56s	remaining: 17.1s
# 130:	learn: 5.0845439	total: 2.58s	remaining: 17.1s
# 131:	learn: 5.0826090	total: 2.59s	remaining: 17.1s
# 132:	learn: 5.0769052	total: 2.61s	remaining: 17s
# 133:	learn: 5.0740680	total: 2.63s	remaining: 17s
# 134:	learn: 5.0702291	total: 2.65s	remaining: 17s
# 135:	learn: 5.0671519	total: 2.67s	remaining: 17s
# 136:	learn: 5.0625627	total: 2.69s	remaining: 16.9s
# 137:	learn: 5.0566912	total: 2.71s	remaining: 16.9s
# 138:	learn: 5.0537453	total: 2.72s	remaining: 16.9s
# 139:	learn: 5.0480329	total: 2.74s	remaining: 16.8s
# 140:	learn: 5.0442484	total: 2.76s	remaining: 16.8s
# 141:	learn: 5.0386604	total: 2.78s	remaining: 16.8s
# 142:	learn: 5.0368255	total: 2.79s	remaining: 16.7s
# 143:	learn: 5.0315579	total: 2.81s	remaining: 16.7s
# 144:	learn: 5.0271666	total: 2.83s	remaining: 16.7s
# 145:	learn: 5.0231896	total: 2.85s	remaining: 16.7s
# 146:	learn: 5.0207190	total: 2.87s	remaining: 16.6s
# 147:	learn: 5.0180025	total: 2.89s	remaining: 16.6s
# 148:	learn: 5.0139690	total: 2.9s	remaining: 16.6s
# 149:	learn: 5.0122417	total: 2.92s	remaining: 16.6s
# 150:	learn: 5.0094559	total: 2.94s	remaining: 16.5s
# 151:	learn: 5.0057038	total: 2.96s	remaining: 16.5s
# 152:	learn: 5.0037425	total: 2.98s	remaining: 16.5s
# 153:	learn: 4.9987146	total: 3s	remaining: 16.5s
# 154:	learn: 4.9961006	total: 3.02s	remaining: 16.5s
# 155:	learn: 4.9905777	total: 3.04s	remaining: 16.4s
# 156:	learn: 4.9855595	total: 3.05s	remaining: 16.4s
# 157:	learn: 4.9820183	total: 3.07s	remaining: 16.4s
# 158:	learn: 4.9790887	total: 3.09s	remaining: 16.3s
# 159:	learn: 4.9752656	total: 3.11s	remaining: 16.3s
# 160:	learn: 4.9743401	total: 3.13s	remaining: 16.3s
# 161:	learn: 4.9722370	total: 3.15s	remaining: 16.3s
# 162:	learn: 4.9710083	total: 3.17s	remaining: 16.3s
# 163:	learn: 4.9686692	total: 3.18s	remaining: 16.2s
# 164:	learn: 4.9632356	total: 3.2s	remaining: 16.2s
# 165:	learn: 4.9611832	total: 3.22s	remaining: 16.2s
# 166:	learn: 4.9597306	total: 3.24s	remaining: 16.1s
# 167:	learn: 4.9573388	total: 3.26s	remaining: 16.1s
# 168:	learn: 4.9543221	total: 3.27s	remaining: 16.1s
# 169:	learn: 4.9522510	total: 3.29s	remaining: 16.1s
# 170:	learn: 4.9492245	total: 3.31s	remaining: 16.1s
# 171:	learn: 4.9461592	total: 3.33s	remaining: 16s
# 172:	learn: 4.9411637	total: 3.35s	remaining: 16s
# 173:	learn: 4.9355369	total: 3.36s	remaining: 16s
# 174:	learn: 4.9312810	total: 3.38s	remaining: 15.9s
# 175:	learn: 4.9291353	total: 3.4s	remaining: 15.9s
# 176:	learn: 4.9257741	total: 3.42s	remaining: 15.9s
# 177:	learn: 4.9229819	total: 3.44s	remaining: 15.9s
# 178:	learn: 4.9203707	total: 3.45s	remaining: 15.8s
# 179:	learn: 4.9161624	total: 3.47s	remaining: 15.8s
# 180:	learn: 4.9140936	total: 3.49s	remaining: 15.8s
# 181:	learn: 4.9120820	total: 3.51s	remaining: 15.8s
# 182:	learn: 4.9099978	total: 3.53s	remaining: 15.7s
# 183:	learn: 4.9074557	total: 3.54s	remaining: 15.7s
# 184:	learn: 4.9057731	total: 3.56s	remaining: 15.7s
# 185:	learn: 4.9035227	total: 3.58s	remaining: 15.7s
# 186:	learn: 4.9005169	total: 3.6s	remaining: 15.7s
# 187:	learn: 4.8979304	total: 3.62s	remaining: 15.6s
# 188:	learn: 4.8928486	total: 3.64s	remaining: 15.6s
# 189:	learn: 4.8898934	total: 3.66s	remaining: 15.6s
# 190:	learn: 4.8863944	total: 3.68s	remaining: 15.6s
# 191:	learn: 4.8843002	total: 3.7s	remaining: 15.6s
# 192:	learn: 4.8822557	total: 3.72s	remaining: 15.6s
# 193:	learn: 4.8797460	total: 3.74s	remaining: 15.5s
# 194:	learn: 4.8781977	total: 3.76s	remaining: 15.5s
# 195:	learn: 4.8759982	total: 3.78s	remaining: 15.5s
# 196:	learn: 4.8719515	total: 3.79s	remaining: 15.5s
# 197:	learn: 4.8635093	total: 3.81s	remaining: 15.4s
# 198:	learn: 4.8609090	total: 3.83s	remaining: 15.4s
# 199:	learn: 4.8591732	total: 3.85s	remaining: 15.4s
# 200:	learn: 4.8567280	total: 3.87s	remaining: 15.4s
# 201:	learn: 4.8529212	total: 3.89s	remaining: 15.4s
# 202:	learn: 4.8497146	total: 3.9s	remaining: 15.3s
# 203:	learn: 4.8463976	total: 3.93s	remaining: 15.3s
# 204:	learn: 4.8443384	total: 3.95s	remaining: 15.3s
# 205:	learn: 4.8385250	total: 3.97s	remaining: 15.3s
# 206:	learn: 4.8328234	total: 3.99s	remaining: 15.3s
# 207:	learn: 4.8297339	total: 4.01s	remaining: 15.3s
# 208:	learn: 4.8221537	total: 4.03s	remaining: 15.2s
# 209:	learn: 4.8188326	total: 4.04s	remaining: 15.2s
# 210:	learn: 4.8155942	total: 4.06s	remaining: 15.2s
# 211:	learn: 4.8133732	total: 4.08s	remaining: 15.2s
# 212:	learn: 4.8060089	total: 4.1s	remaining: 15.1s
# 213:	learn: 4.8020937	total: 4.12s	remaining: 15.1s
# 214:	learn: 4.7994627	total: 4.13s	remaining: 15.1s
# 215:	learn: 4.7972952	total: 4.15s	remaining: 15.1s
# 216:	learn: 4.7934364	total: 4.17s	remaining: 15s
# 217:	learn: 4.7896721	total: 4.19s	remaining: 15s
# 218:	learn: 4.7835153	total: 4.21s	remaining: 15s
# 219:	learn: 4.7766493	total: 4.22s	remaining: 15s
# 220:	learn: 4.7734065	total: 4.24s	remaining: 15s
# 221:	learn: 4.7707539	total: 4.26s	remaining: 14.9s
# 222:	learn: 4.7663556	total: 4.28s	remaining: 14.9s
# 223:	learn: 4.7633454	total: 4.29s	remaining: 14.9s
# 224:	learn: 4.7599855	total: 4.31s	remaining: 14.9s
# 225:	learn: 4.7571660	total: 4.33s	remaining: 14.8s
# 226:	learn: 4.7519739	total: 4.35s	remaining: 14.8s
# 227:	learn: 4.7412802	total: 4.37s	remaining: 14.8s
# 228:	learn: 4.7375888	total: 4.39s	remaining: 14.8s
# 229:	learn: 4.7344369	total: 4.41s	remaining: 14.8s
# 230:	learn: 4.7315562	total: 4.42s	remaining: 14.7s
# 231:	learn: 4.7285755	total: 4.44s	remaining: 14.7s
# 232:	learn: 4.7245766	total: 4.46s	remaining: 14.7s
# 233:	learn: 4.7217757	total: 4.48s	remaining: 14.7s
# 234:	learn: 4.7189309	total: 4.5s	remaining: 14.7s
# 235:	learn: 4.7155395	total: 4.52s	remaining: 14.6s
# 236:	learn: 4.7101834	total: 4.54s	remaining: 14.6s
# 237:	learn: 4.7071577	total: 4.56s	remaining: 14.6s
# 238:	learn: 4.7045282	total: 4.58s	remaining: 14.6s
# 239:	learn: 4.6995933	total: 4.6s	remaining: 14.6s
# 240:	learn: 4.6929700	total: 4.62s	remaining: 14.5s
# 241:	learn: 4.6905192	total: 4.64s	remaining: 14.5s
# 242:	learn: 4.6873175	total: 4.66s	remaining: 14.5s
# 243:	learn: 4.6795589	total: 4.68s	remaining: 14.5s
# 244:	learn: 4.6763273	total: 4.7s	remaining: 14.5s
# 245:	learn: 4.6729585	total: 4.72s	remaining: 14.5s
# 246:	learn: 4.6672692	total: 4.73s	remaining: 14.4s
# 247:	learn: 4.6645590	total: 4.75s	remaining: 14.4s
# 248:	learn: 4.6594022	total: 4.77s	remaining: 14.4s
# 249:	learn: 4.6569056	total: 4.79s	remaining: 14.4s
# 250:	learn: 4.6544899	total: 4.81s	remaining: 14.3s
# 251:	learn: 4.6483213	total: 4.83s	remaining: 14.3s
# 252:	learn: 4.6455569	total: 4.85s	remaining: 14.3s
# 253:	learn: 4.6350837	total: 4.87s	remaining: 14.3s
# 254:	learn: 4.6324357	total: 4.89s	remaining: 14.3s
# 255:	learn: 4.6285171	total: 4.91s	remaining: 14.3s
# 256:	learn: 4.6230361	total: 4.92s	remaining: 14.2s
# 257:	learn: 4.6197338	total: 4.95s	remaining: 14.2s
# 258:	learn: 4.6103136	total: 4.97s	remaining: 14.2s
# 259:	learn: 4.6054535	total: 4.99s	remaining: 14.2s
# 260:	learn: 4.6026545	total: 5.01s	remaining: 14.2s
# 261:	learn: 4.5998780	total: 5.04s	remaining: 14.2s
# 262:	learn: 4.5931761	total: 5.06s	remaining: 14.2s
# 263:	learn: 4.5889958	total: 5.07s	remaining: 14.1s
# 264:	learn: 4.5816309	total: 5.09s	remaining: 14.1s
# 265:	learn: 4.5722993	total: 5.11s	remaining: 14.1s
# 266:	learn: 4.5697002	total: 5.13s	remaining: 14.1s
# 267:	learn: 4.5673301	total: 5.15s	remaining: 14.1s
# 268:	learn: 4.5641917	total: 5.17s	remaining: 14s
# 269:	learn: 4.5587030	total: 5.19s	remaining: 14s
# 270:	learn: 4.5542388	total: 5.21s	remaining: 14s
# 271:	learn: 4.5509064	total: 5.22s	remaining: 14s
# 272:	learn: 4.5476159	total: 5.24s	remaining: 14s
# 273:	learn: 4.5446329	total: 5.27s	remaining: 14s
# 274:	learn: 4.5418743	total: 5.28s	remaining: 13.9s
# 275:	learn: 4.5382631	total: 5.3s	remaining: 13.9s
# 276:	learn: 4.5329031	total: 5.32s	remaining: 13.9s
# 277:	learn: 4.5302863	total: 5.34s	remaining: 13.9s
# 278:	learn: 4.5228856	total: 5.36s	remaining: 13.8s
# 279:	learn: 4.5190493	total: 5.38s	remaining: 13.8s
# 280:	learn: 4.5158608	total: 5.39s	remaining: 13.8s
# 281:	learn: 4.5132980	total: 5.41s	remaining: 13.8s
# 282:	learn: 4.5042793	total: 5.43s	remaining: 13.8s
# 283:	learn: 4.5000841	total: 5.45s	remaining: 13.7s
# 284:	learn: 4.4977111	total: 5.47s	remaining: 13.7s
# 285:	learn: 4.4904972	total: 5.49s	remaining: 13.7s
# 286:	learn: 4.4841465	total: 5.51s	remaining: 13.7s
# 287:	learn: 4.4768917	total: 5.53s	remaining: 13.7s
# 288:	learn: 4.4748120	total: 5.54s	remaining: 13.6s
# 289:	learn: 4.4665247	total: 5.56s	remaining: 13.6s
# 290:	learn: 4.4634357	total: 5.58s	remaining: 13.6s
# 291:	learn: 4.4597202	total: 5.6s	remaining: 13.6s
# 292:	learn: 4.4508477	total: 5.62s	remaining: 13.6s
# 293:	learn: 4.4482671	total: 5.64s	remaining: 13.5s
# 294:	learn: 4.4444217	total: 5.66s	remaining: 13.5s
# 295:	learn: 4.4417639	total: 5.68s	remaining: 13.5s
# 296:	learn: 4.4393699	total: 5.7s	remaining: 13.5s
# 297:	learn: 4.4330762	total: 5.72s	remaining: 13.5s
# 298:	learn: 4.4264725	total: 5.74s	remaining: 13.5s
# 299:	learn: 4.4240499	total: 5.76s	remaining: 13.4s
# 300:	learn: 4.4220477	total: 5.78s	remaining: 13.4s
# 301:	learn: 4.4193508	total: 5.81s	remaining: 13.4s
# 302:	learn: 4.4157005	total: 5.83s	remaining: 13.4s
# 303:	learn: 4.4087784	total: 5.85s	remaining: 13.4s
# 304:	learn: 4.4052518	total: 5.87s	remaining: 13.4s
# 305:	learn: 4.4014276	total: 5.89s	remaining: 13.4s
# 306:	learn: 4.3992245	total: 5.91s	remaining: 13.3s
# 307:	learn: 4.3928458	total: 5.93s	remaining: 13.3s
# 308:	learn: 4.3907105	total: 5.94s	remaining: 13.3s
# 309:	learn: 4.3883579	total: 5.97s	remaining: 13.3s
# 310:	learn: 4.3860171	total: 5.99s	remaining: 13.3s
# 311:	learn: 4.3808420	total: 6s	remaining: 13.2s
# 312:	learn: 4.3772946	total: 6.02s	remaining: 13.2s
# 313:	learn: 4.3752224	total: 6.05s	remaining: 13.2s
# 314:	learn: 4.3733564	total: 6.07s	remaining: 13.2s
# 315:	learn: 4.3711066	total: 6.08s	remaining: 13.2s
# 316:	learn: 4.3642437	total: 6.1s	remaining: 13.1s
# 317:	learn: 4.3570141	total: 6.12s	remaining: 13.1s
# 318:	learn: 4.3550101	total: 6.14s	remaining: 13.1s
# 319:	learn: 4.3515893	total: 6.16s	remaining: 13.1s
# 320:	learn: 4.3447826	total: 6.18s	remaining: 13.1s
# 321:	learn: 4.3383788	total: 6.2s	remaining: 13.1s
# 322:	learn: 4.3351505	total: 6.22s	remaining: 13s
# 323:	learn: 4.3325037	total: 6.24s	remaining: 13s
# 324:	learn: 4.3304324	total: 6.26s	remaining: 13s
# 325:	learn: 4.3267338	total: 6.28s	remaining: 13s
# 326:	learn: 4.3237405	total: 6.3s	remaining: 13s
# 327:	learn: 4.3212646	total: 6.32s	remaining: 12.9s
# 328:	learn: 4.3142313	total: 6.34s	remaining: 12.9s
# 329:	learn: 4.3109095	total: 6.36s	remaining: 12.9s
# 330:	learn: 4.3090450	total: 6.37s	remaining: 12.9s
# 331:	learn: 4.3069009	total: 6.39s	remaining: 12.9s
# 332:	learn: 4.3035718	total: 6.42s	remaining: 12.9s
# 333:	learn: 4.2974702	total: 6.44s	remaining: 12.8s
# 334:	learn: 4.2948428	total: 6.46s	remaining: 12.8s
# 335:	learn: 4.2909365	total: 6.48s	remaining: 12.8s
# 336:	learn: 4.2887191	total: 6.5s	remaining: 12.8s
# 337:	learn: 4.2803970	total: 6.52s	remaining: 12.8s
# 338:	learn: 4.2771583	total: 6.54s	remaining: 12.8s
# 339:	learn: 4.2747972	total: 6.56s	remaining: 12.7s
# 340:	learn: 4.2685177	total: 6.58s	remaining: 12.7s
# 341:	learn: 4.2662482	total: 6.59s	remaining: 12.7s
# 342:	learn: 4.2595730	total: 6.61s	remaining: 12.7s
# 343:	learn: 4.2547723	total: 6.63s	remaining: 12.7s
# 344:	learn: 4.2524344	total: 6.65s	remaining: 12.6s
# 345:	learn: 4.2499507	total: 6.67s	remaining: 12.6s
# 346:	learn: 4.2481851	total: 6.69s	remaining: 12.6s
# 347:	learn: 4.2464180	total: 6.71s	remaining: 12.6s
# 348:	learn: 4.2442652	total: 6.72s	remaining: 12.5s
# 349:	learn: 4.2383295	total: 6.74s	remaining: 12.5s
# 350:	learn: 4.2303937	total: 6.76s	remaining: 12.5s
# 351:	learn: 4.2268678	total: 6.78s	remaining: 12.5s
# 352:	learn: 4.2206380	total: 6.8s	remaining: 12.5s
# 353:	learn: 4.2172143	total: 6.82s	remaining: 12.4s
# 354:	learn: 4.2116592	total: 6.83s	remaining: 12.4s
# 355:	learn: 4.2095456	total: 6.85s	remaining: 12.4s
# 356:	learn: 4.2076752	total: 6.87s	remaining: 12.4s
# 357:	learn: 4.2055671	total: 6.88s	remaining: 12.3s
# 358:	learn: 4.2024301	total: 6.9s	remaining: 12.3s
# 359:	learn: 4.2003522	total: 6.93s	remaining: 12.3s
# 360:	learn: 4.1928980	total: 6.95s	remaining: 12.3s
# 361:	learn: 4.1866516	total: 6.96s	remaining: 12.3s
# 362:	learn: 4.1809518	total: 6.98s	remaining: 12.3s
# 363:	learn: 4.1747982	total: 7s	remaining: 12.2s
# 364:	learn: 4.1728026	total: 7.03s	remaining: 12.2s
# 365:	learn: 4.1703543	total: 7.05s	remaining: 12.2s
# 366:	learn: 4.1683514	total: 7.07s	remaining: 12.2s
# 367:	learn: 4.1630115	total: 7.08s	remaining: 12.2s
# 368:	learn: 4.1608431	total: 7.1s	remaining: 12.1s
# 369:	learn: 4.1585333	total: 7.12s	remaining: 12.1s
# 370:	learn: 4.1519979	total: 7.15s	remaining: 12.1s
# 371:	learn: 4.1456761	total: 7.18s	remaining: 12.1s
# 372:	learn: 4.1436325	total: 7.2s	remaining: 12.1s
# 373:	learn: 4.1381235	total: 7.21s	remaining: 12.1s
# 374:	learn: 4.1332645	total: 7.23s	remaining: 12.1s
# 375:	learn: 4.1304575	total: 7.25s	remaining: 12s
# 376:	learn: 4.1284702	total: 7.26s	remaining: 12s
# 377:	learn: 4.1264672	total: 7.28s	remaining: 12s
# 378:	learn: 4.1245772	total: 7.3s	remaining: 12s
# 379:	learn: 4.1227838	total: 7.32s	remaining: 11.9s
# 380:	learn: 4.1189623	total: 7.34s	remaining: 11.9s
# 381:	learn: 4.1171106	total: 7.36s	remaining: 11.9s
# 382:	learn: 4.1147516	total: 7.38s	remaining: 11.9s
# 383:	learn: 4.1116450	total: 7.39s	remaining: 11.9s
# 384:	learn: 4.1096251	total: 7.41s	remaining: 11.8s
# 385:	learn: 4.1068255	total: 7.43s	remaining: 11.8s
# 386:	learn: 4.1051725	total: 7.45s	remaining: 11.8s
# 387:	learn: 4.0983525	total: 7.46s	remaining: 11.8s
# 388:	learn: 4.0960748	total: 7.49s	remaining: 11.8s
# 389:	learn: 4.0917354	total: 7.5s	remaining: 11.7s
# 390:	learn: 4.0898049	total: 7.52s	remaining: 11.7s
# 391:	learn: 4.0867509	total: 7.54s	remaining: 11.7s
# 392:	learn: 4.0840574	total: 7.56s	remaining: 11.7s
# 393:	learn: 4.0823104	total: 7.58s	remaining: 11.7s
# 394:	learn: 4.0767358	total: 7.6s	remaining: 11.6s
# 395:	learn: 4.0737096	total: 7.62s	remaining: 11.6s
# 396:	learn: 4.0719020	total: 7.64s	remaining: 11.6s
# 397:	learn: 4.0698910	total: 7.66s	remaining: 11.6s
# 398:	learn: 4.0672559	total: 7.68s	remaining: 11.6s
# 399:	learn: 4.0654417	total: 7.7s	remaining: 11.5s
# 400:	learn: 4.0635796	total: 7.72s	remaining: 11.5s
# 401:	learn: 4.0616062	total: 7.74s	remaining: 11.5s
# 402:	learn: 4.0600474	total: 7.76s	remaining: 11.5s
# 403:	learn: 4.0550974	total: 7.78s	remaining: 11.5s
# 404:	learn: 4.0530898	total: 7.79s	remaining: 11.5s
# 405:	learn: 4.0494346	total: 7.82s	remaining: 11.4s
# 406:	learn: 4.0439244	total: 7.84s	remaining: 11.4s
# 407:	learn: 4.0383233	total: 7.86s	remaining: 11.4s
# 408:	learn: 4.0364132	total: 7.88s	remaining: 11.4s
# 409:	learn: 4.0348045	total: 7.89s	remaining: 11.4s
# 410:	learn: 4.0327327	total: 7.91s	remaining: 11.3s
# 411:	learn: 4.0279773	total: 7.93s	remaining: 11.3s
# 412:	learn: 4.0261810	total: 7.95s	remaining: 11.3s
# 413:	learn: 4.0242666	total: 7.97s	remaining: 11.3s
# 414:	learn: 4.0194022	total: 7.99s	remaining: 11.3s
# 415:	learn: 4.0170574	total: 8.01s	remaining: 11.2s
# 416:	learn: 4.0154687	total: 8.03s	remaining: 11.2s
# 417:	learn: 4.0139399	total: 8.04s	remaining: 11.2s
# 418:	learn: 4.0089587	total: 8.06s	remaining: 11.2s
# 419:	learn: 4.0049780	total: 8.08s	remaining: 11.2s
# 420:	learn: 4.0026298	total: 8.1s	remaining: 11.1s
# 421:	learn: 4.0005791	total: 8.12s	remaining: 11.1s
# 422:	learn: 3.9966116	total: 8.14s	remaining: 11.1s
# 423:	learn: 3.9895201	total: 8.15s	remaining: 11.1s
# 424:	learn: 3.9877408	total: 8.17s	remaining: 11.1s
# 425:	learn: 3.9860299	total: 8.19s	remaining: 11s
# 426:	learn: 3.9809479	total: 8.21s	remaining: 11s
# 427:	learn: 3.9789380	total: 8.23s	remaining: 11s
# 428:	learn: 3.9775913	total: 8.24s	remaining: 11s
# 429:	learn: 3.9736556	total: 8.26s	remaining: 11s
# 430:	learn: 3.9676060	total: 8.29s	remaining: 10.9s
# 431:	learn: 3.9659601	total: 8.31s	remaining: 10.9s
# 432:	learn: 3.9640220	total: 8.33s	remaining: 10.9s
# 433:	learn: 3.9596017	total: 8.35s	remaining: 10.9s
# 434:	learn: 3.9570456	total: 8.37s	remaining: 10.9s
# 435:	learn: 3.9526180	total: 8.38s	remaining: 10.8s
# 436:	learn: 3.9511091	total: 8.4s	remaining: 10.8s
# 437:	learn: 3.9493494	total: 8.42s	remaining: 10.8s
# 438:	learn: 3.9477422	total: 8.44s	remaining: 10.8s
# 439:	learn: 3.9461949	total: 8.46s	remaining: 10.8s
# 440:	learn: 3.9444681	total: 8.47s	remaining: 10.7s
# 441:	learn: 3.9414761	total: 8.49s	remaining: 10.7s
# 442:	learn: 3.9397359	total: 8.51s	remaining: 10.7s
# 443:	learn: 3.9382222	total: 8.53s	remaining: 10.7s
# 444:	learn: 3.9361092	total: 8.55s	remaining: 10.7s
# 445:	learn: 3.9336756	total: 8.57s	remaining: 10.6s
# 446:	learn: 3.9280551	total: 8.59s	remaining: 10.6s
# 447:	learn: 3.9260155	total: 8.61s	remaining: 10.6s
# 448:	learn: 3.9221622	total: 8.62s	remaining: 10.6s
# 449:	learn: 3.9205249	total: 8.64s	remaining: 10.6s
# 450:	learn: 3.9187022	total: 8.66s	remaining: 10.5s
# 451:	learn: 3.9170855	total: 8.68s	remaining: 10.5s
# 452:	learn: 3.9155908	total: 8.7s	remaining: 10.5s
# 453:	learn: 3.9141770	total: 8.71s	remaining: 10.5s
# 454:	learn: 3.9125780	total: 8.73s	remaining: 10.5s
# 455:	learn: 3.9093802	total: 8.75s	remaining: 10.4s
# 456:	learn: 3.9077146	total: 8.77s	remaining: 10.4s
# 457:	learn: 3.9035215	total: 8.79s	remaining: 10.4s
# 458:	learn: 3.9014539	total: 8.81s	remaining: 10.4s
# 459:	learn: 3.9001251	total: 8.82s	remaining: 10.4s
# 460:	learn: 3.8938507	total: 8.85s	remaining: 10.3s
# 461:	learn: 3.8914186	total: 8.87s	remaining: 10.3s
# 462:	learn: 3.8860777	total: 8.88s	remaining: 10.3s
# 463:	learn: 3.8843944	total: 8.9s	remaining: 10.3s
# 464:	learn: 3.8828059	total: 8.92s	remaining: 10.3s
# 465:	learn: 3.8809085	total: 8.94s	remaining: 10.2s
# 466:	learn: 3.8780571	total: 8.96s	remaining: 10.2s
# 467:	learn: 3.8765595	total: 8.97s	remaining: 10.2s
# 468:	learn: 3.8751773	total: 8.99s	remaining: 10.2s
# 469:	learn: 3.8734762	total: 9.01s	remaining: 10.2s
# 470:	learn: 3.8714899	total: 9.03s	remaining: 10.1s
# 471:	learn: 3.8663491	total: 9.05s	remaining: 10.1s
# 472:	learn: 3.8646923	total: 9.07s	remaining: 10.1s
# 473:	learn: 3.8630011	total: 9.09s	remaining: 10.1s
# 474:	learn: 3.8576456	total: 9.11s	remaining: 10.1s
# 475:	learn: 3.8557114	total: 9.12s	remaining: 10s
# 476:	learn: 3.8543156	total: 9.14s	remaining: 10s
# 477:	learn: 3.8501675	total: 9.16s	remaining: 10s
# 478:	learn: 3.8486282	total: 9.18s	remaining: 9.98s
# 479:	learn: 3.8468250	total: 9.19s	remaining: 9.96s
# 480:	learn: 3.8453349	total: 9.21s	remaining: 9.94s
# 481:	learn: 3.8438892	total: 9.23s	remaining: 9.92s
# 482:	learn: 3.8384545	total: 9.25s	remaining: 9.9s
# 483:	learn: 3.8367360	total: 9.27s	remaining: 9.88s
# 484:	learn: 3.8323309	total: 9.29s	remaining: 9.86s
# 485:	learn: 3.8308798	total: 9.31s	remaining: 9.84s
# 486:	learn: 3.8292590	total: 9.32s	remaining: 9.82s
# 487:	learn: 3.8248718	total: 9.34s	remaining: 9.8s
# 488:	learn: 3.8233213	total: 9.36s	remaining: 9.78s
# 489:	learn: 3.8217227	total: 9.38s	remaining: 9.76s
# 490:	learn: 3.8203734	total: 9.41s	remaining: 9.76s
# 491:	learn: 3.8190402	total: 9.43s	remaining: 9.74s
# 492:	learn: 3.8149633	total: 9.45s	remaining: 9.72s
# 493:	learn: 3.8130220	total: 9.47s	remaining: 9.7s
# 494:	learn: 3.8109092	total: 9.49s	remaining: 9.68s
# 495:	learn: 3.8039483	total: 9.51s	remaining: 9.66s
# 496:	learn: 3.8024514	total: 9.53s	remaining: 9.64s
# 497:	learn: 3.8012618	total: 9.55s	remaining: 9.63s
# 498:	learn: 3.7998723	total: 9.57s	remaining: 9.6s
# 499:	learn: 3.7985118	total: 9.59s	remaining: 9.59s
# 500:	learn: 3.7973131	total: 9.6s	remaining: 9.56s
# 501:	learn: 3.7960251	total: 9.62s	remaining: 9.54s
# 502:	learn: 3.7939470	total: 9.64s	remaining: 9.52s
# 503:	learn: 3.7883275	total: 9.66s	remaining: 9.51s
# 504:	learn: 3.7840177	total: 9.68s	remaining: 9.48s
# 505:	learn: 3.7825165	total: 9.69s	remaining: 9.46s
# 506:	learn: 3.7813902	total: 9.71s	remaining: 9.44s
# 507:	learn: 3.7745852	total: 9.73s	remaining: 9.42s
# 508:	learn: 3.7729903	total: 9.74s	remaining: 9.4s
# 509:	learn: 3.7715692	total: 9.76s	remaining: 9.38s
# 510:	learn: 3.7703223	total: 9.78s	remaining: 9.36s
# 511:	learn: 3.7686582	total: 9.8s	remaining: 9.34s
# 512:	learn: 3.7670110	total: 9.82s	remaining: 9.32s
# 513:	learn: 3.7659361	total: 9.84s	remaining: 9.3s
# 514:	learn: 3.7645464	total: 9.86s	remaining: 9.28s
# 515:	learn: 3.7623097	total: 9.88s	remaining: 9.27s
# 516:	learn: 3.7582422	total: 9.9s	remaining: 9.25s
# 517:	learn: 3.7546331	total: 9.92s	remaining: 9.23s
# 518:	learn: 3.7523415	total: 9.94s	remaining: 9.21s
# 519:	learn: 3.7476063	total: 9.96s	remaining: 9.2s
# 520:	learn: 3.7433662	total: 9.98s	remaining: 9.18s
# 521:	learn: 3.7419506	total: 10s	remaining: 9.17s
# 522:	learn: 3.7384317	total: 10s	remaining: 9.15s
# 523:	learn: 3.7370566	total: 10.1s	remaining: 9.13s
# 524:	learn: 3.7358314	total: 10.1s	remaining: 9.11s
# 525:	learn: 3.7320909	total: 10.1s	remaining: 9.09s
# 526:	learn: 3.7307246	total: 10.1s	remaining: 9.07s
# 527:	learn: 3.7272843	total: 10.1s	remaining: 9.05s
# 528:	learn: 3.7236774	total: 10.1s	remaining: 9.03s
# 529:	learn: 3.7203216	total: 10.2s	remaining: 9.01s
# 530:	learn: 3.7189645	total: 10.2s	remaining: 8.99s
# 531:	learn: 3.7174454	total: 10.2s	remaining: 8.97s
# 532:	learn: 3.7152083	total: 10.2s	remaining: 8.95s
# 533:	learn: 3.7140147	total: 10.2s	remaining: 8.93s
# 534:	learn: 3.7096790	total: 10.3s	remaining: 8.91s
# 535:	learn: 3.7083633	total: 10.3s	remaining: 8.89s
# 536:	learn: 3.7053749	total: 10.3s	remaining: 8.87s
# 537:	learn: 3.7013872	total: 10.3s	remaining: 8.86s
# 538:	learn: 3.6990965	total: 10.3s	remaining: 8.84s
# 539:	learn: 3.6977221	total: 10.4s	remaining: 8.82s
# 540:	learn: 3.6963124	total: 10.4s	remaining: 8.8s
# 541:	learn: 3.6949711	total: 10.4s	remaining: 8.79s
# 542:	learn: 3.6907894	total: 10.4s	remaining: 8.76s
# 543:	learn: 3.6896681	total: 10.4s	remaining: 8.74s
# 544:	learn: 3.6881978	total: 10.5s	remaining: 8.73s
# 545:	learn: 3.6838678	total: 10.5s	remaining: 8.71s
# 546:	learn: 3.6826369	total: 10.5s	remaining: 8.69s
# 547:	learn: 3.6812839	total: 10.5s	remaining: 8.66s
# 548:	learn: 3.6775065	total: 10.5s	remaining: 8.65s
# 549:	learn: 3.6763714	total: 10.5s	remaining: 8.63s
# 550:	learn: 3.6752817	total: 10.6s	remaining: 8.61s
# 551:	learn: 3.6715244	total: 10.6s	remaining: 8.59s
# 552:	learn: 3.6701830	total: 10.6s	remaining: 8.57s
# 553:	learn: 3.6670444	total: 10.6s	remaining: 8.55s
# 554:	learn: 3.6630273	total: 10.6s	remaining: 8.53s
# 555:	learn: 3.6581932	total: 10.7s	remaining: 8.51s
# 556:	learn: 3.6566906	total: 10.7s	remaining: 8.49s
# 557:	learn: 3.6554617	total: 10.7s	remaining: 8.47s
# 558:	learn: 3.6535876	total: 10.7s	remaining: 8.46s
# 559:	learn: 3.6497566	total: 10.7s	remaining: 8.44s
# 560:	learn: 3.6485967	total: 10.8s	remaining: 8.42s
# 561:	learn: 3.6463671	total: 10.8s	remaining: 8.4s
# 562:	learn: 3.6432414	total: 10.8s	remaining: 8.38s
# 563:	learn: 3.6418603	total: 10.8s	remaining: 8.36s
# 564:	learn: 3.6405250	total: 10.8s	remaining: 8.34s
# 565:	learn: 3.6369923	total: 10.9s	remaining: 8.32s
# 566:	learn: 3.6355741	total: 10.9s	remaining: 8.3s
# 567:	learn: 3.6341533	total: 10.9s	remaining: 8.29s
# 568:	learn: 3.6328916	total: 10.9s	remaining: 8.27s
# 569:	learn: 3.6315558	total: 10.9s	remaining: 8.25s
# 570:	learn: 3.6302545	total: 11s	remaining: 8.23s
# 571:	learn: 3.6288547	total: 11s	remaining: 8.21s
# 572:	learn: 3.6248053	total: 11s	remaining: 8.19s
# 573:	learn: 3.6235507	total: 11s	remaining: 8.18s
# 574:	learn: 3.6222485	total: 11s	remaining: 8.16s
# 575:	learn: 3.6204994	total: 11.1s	remaining: 8.14s
# 576:	learn: 3.6190370	total: 11.1s	remaining: 8.12s
# 577:	learn: 3.6178618	total: 11.1s	remaining: 8.1s
# 578:	learn: 3.6162258	total: 11.1s	remaining: 8.09s
# 579:	learn: 3.6125741	total: 11.1s	remaining: 8.07s
# 580:	learn: 3.6091113	total: 11.2s	remaining: 8.05s
# 581:	learn: 3.6066620	total: 11.2s	remaining: 8.03s
# 582:	learn: 3.6056107	total: 11.2s	remaining: 8.02s
# 583:	learn: 3.6038434	total: 11.2s	remaining: 8s
# 584:	learn: 3.6026054	total: 11.3s	remaining: 7.98s
# 585:	learn: 3.6012328	total: 11.3s	remaining: 7.97s
# 586:	learn: 3.5998402	total: 11.3s	remaining: 7.95s
# 587:	learn: 3.5973170	total: 11.3s	remaining: 7.93s
# 588:	learn: 3.5939470	total: 11.3s	remaining: 7.91s
# 589:	learn: 3.5912248	total: 11.4s	remaining: 7.89s
# 590:	learn: 3.5900659	total: 11.4s	remaining: 7.87s
# 591:	learn: 3.5888029	total: 11.4s	remaining: 7.85s
# 592:	learn: 3.5859200	total: 11.4s	remaining: 7.83s
# 593:	learn: 3.5848193	total: 11.4s	remaining: 7.81s
# 594:	learn: 3.5809264	total: 11.5s	remaining: 7.79s
# 595:	learn: 3.5797170	total: 11.5s	remaining: 7.78s
# 596:	learn: 3.5770429	total: 11.5s	remaining: 7.76s
# 597:	learn: 3.5757616	total: 11.5s	remaining: 7.74s
# 598:	learn: 3.5716295	total: 11.5s	remaining: 7.72s
# 599:	learn: 3.5704477	total: 11.6s	remaining: 7.7s
# 600:	learn: 3.5690896	total: 11.6s	remaining: 7.68s
# 601:	learn: 3.5660994	total: 11.6s	remaining: 7.66s
# 602:	learn: 3.5649663	total: 11.6s	remaining: 7.64s
# 603:	learn: 3.5637544	total: 11.6s	remaining: 7.62s
# 604:	learn: 3.5610079	total: 11.6s	remaining: 7.6s
# 605:	learn: 3.5598676	total: 11.7s	remaining: 7.58s
# 606:	learn: 3.5589001	total: 11.7s	remaining: 7.56s
# 607:	learn: 3.5573841	total: 11.7s	remaining: 7.54s
# 608:	learn: 3.5546151	total: 11.7s	remaining: 7.53s
# 609:	learn: 3.5523133	total: 11.7s	remaining: 7.51s
# 610:	learn: 3.5512342	total: 11.8s	remaining: 7.49s
# 611:	learn: 3.5498171	total: 11.8s	remaining: 7.47s
# 612:	learn: 3.5485026	total: 11.8s	remaining: 7.45s
# 613:	learn: 3.5474364	total: 11.8s	remaining: 7.43s
# 614:	learn: 3.5462316	total: 11.8s	remaining: 7.41s
# 615:	learn: 3.5431093	total: 11.9s	remaining: 7.39s
# 616:	learn: 3.5398827	total: 11.9s	remaining: 7.38s
# 617:	learn: 3.5363165	total: 11.9s	remaining: 7.36s
# 618:	learn: 3.5350654	total: 11.9s	remaining: 7.34s
# 619:	learn: 3.5319072	total: 11.9s	remaining: 7.32s
# 620:	learn: 3.5286541	total: 12s	remaining: 7.3s
# 621:	learn: 3.5279072	total: 12s	remaining: 7.29s
# 622:	learn: 3.5268110	total: 12s	remaining: 7.26s
# 623:	learn: 3.5223131	total: 12s	remaining: 7.25s
# 624:	learn: 3.5212195	total: 12s	remaining: 7.22s
# 625:	learn: 3.5201221	total: 12.1s	remaining: 7.21s
# 626:	learn: 3.5191979	total: 12.1s	remaining: 7.18s
# 627:	learn: 3.5181810	total: 12.1s	remaining: 7.17s
# 628:	learn: 3.5142497	total: 12.1s	remaining: 7.15s
# 629:	learn: 3.5131971	total: 12.1s	remaining: 7.13s
# 630:	learn: 3.5083337	total: 12.2s	remaining: 7.11s
# 631:	learn: 3.5048150	total: 12.2s	remaining: 7.09s
# 632:	learn: 3.5006371	total: 12.2s	remaining: 7.07s
# 633:	learn: 3.4967584	total: 12.2s	remaining: 7.05s
# 634:	learn: 3.4954810	total: 12.2s	remaining: 7.03s
# 635:	learn: 3.4919171	total: 12.2s	remaining: 7.01s
# 636:	learn: 3.4891104	total: 12.3s	remaining: 6.99s
# 637:	learn: 3.4872168	total: 12.3s	remaining: 6.98s
# 638:	learn: 3.4859883	total: 12.3s	remaining: 6.96s
# 639:	learn: 3.4833581	total: 12.3s	remaining: 6.94s
# 640:	learn: 3.4804247	total: 12.4s	remaining: 6.92s
# 641:	learn: 3.4793056	total: 12.4s	remaining: 6.9s
# 642:	learn: 3.4782416	total: 12.4s	remaining: 6.88s
# 643:	learn: 3.4769778	total: 12.4s	remaining: 6.86s
# 644:	learn: 3.4758769	total: 12.4s	remaining: 6.84s
# 645:	learn: 3.4747314	total: 12.4s	remaining: 6.82s
# 646:	learn: 3.4721059	total: 12.5s	remaining: 6.8s
# 647:	learn: 3.4708676	total: 12.5s	remaining: 6.78s
# 648:	learn: 3.4680640	total: 12.5s	remaining: 6.76s
# 649:	learn: 3.4652898	total: 12.5s	remaining: 6.74s
# 650:	learn: 3.4643462	total: 12.5s	remaining: 6.72s
# 651:	learn: 3.4612990	total: 12.6s	remaining: 6.7s
# 652:	learn: 3.4602599	total: 12.6s	remaining: 6.68s
# 653:	learn: 3.4587059	total: 12.6s	remaining: 6.66s
# 654:	learn: 3.4575096	total: 12.6s	remaining: 6.65s
# 655:	learn: 3.4567297	total: 12.6s	remaining: 6.63s
# 656:	learn: 3.4554353	total: 12.7s	remaining: 6.61s
# 657:	learn: 3.4522174	total: 12.7s	remaining: 6.59s
# 658:	learn: 3.4494032	total: 12.7s	remaining: 6.57s
# 659:	learn: 3.4485826	total: 12.7s	remaining: 6.55s
# 660:	learn: 3.4473540	total: 12.7s	remaining: 6.53s
# 661:	learn: 3.4462723	total: 12.8s	remaining: 6.51s
# 662:	learn: 3.4451776	total: 12.8s	remaining: 6.49s
# 663:	learn: 3.4426525	total: 12.8s	remaining: 6.47s
# 664:	learn: 3.4414417	total: 12.8s	remaining: 6.45s
# 665:	learn: 3.4401614	total: 12.8s	remaining: 6.43s
# 666:	learn: 3.4363732	total: 12.8s	remaining: 6.41s
# 667:	learn: 3.4334660	total: 12.9s	remaining: 6.39s
# 668:	learn: 3.4294049	total: 12.9s	remaining: 6.37s
# 669:	learn: 3.4281966	total: 12.9s	remaining: 6.36s
# 670:	learn: 3.4269955	total: 12.9s	remaining: 6.34s
# 671:	learn: 3.4240307	total: 12.9s	remaining: 6.32s
# 672:	learn: 3.4230448	total: 13s	remaining: 6.3s
# 673:	learn: 3.4219495	total: 13s	remaining: 6.28s
# 674:	learn: 3.4207147	total: 13s	remaining: 6.26s
# 675:	learn: 3.4183938	total: 13s	remaining: 6.24s
# 676:	learn: 3.4152312	total: 13s	remaining: 6.22s
# 677:	learn: 3.4140493	total: 13.1s	remaining: 6.2s
# 678:	learn: 3.4130844	total: 13.1s	remaining: 6.18s
# 679:	learn: 3.4112897	total: 13.1s	remaining: 6.17s
# 680:	learn: 3.4083304	total: 13.1s	remaining: 6.15s
# 681:	learn: 3.4057286	total: 13.1s	remaining: 6.13s
# 682:	learn: 3.4030465	total: 13.2s	remaining: 6.11s
# 683:	learn: 3.4007834	total: 13.2s	remaining: 6.09s
# 684:	learn: 3.3997805	total: 13.2s	remaining: 6.07s
# 685:	learn: 3.3986527	total: 13.2s	remaining: 6.05s
# 686:	learn: 3.3976229	total: 13.2s	remaining: 6.03s
# 687:	learn: 3.3947165	total: 13.3s	remaining: 6.01s
# 688:	learn: 3.3907358	total: 13.3s	remaining: 5.99s
# 689:	learn: 3.3895695	total: 13.3s	remaining: 5.97s
# 690:	learn: 3.3883764	total: 13.3s	remaining: 5.95s
# 691:	learn: 3.3872158	total: 13.3s	remaining: 5.93s
# 692:	learn: 3.3847597	total: 13.3s	remaining: 5.91s
# 693:	learn: 3.3832598	total: 13.4s	remaining: 5.89s
# 694:	learn: 3.3783743	total: 13.4s	remaining: 5.87s
# 695:	learn: 3.3769712	total: 13.4s	remaining: 5.86s
# 696:	learn: 3.3736531	total: 13.4s	remaining: 5.84s
# 697:	learn: 3.3725350	total: 13.4s	remaining: 5.82s
# 698:	learn: 3.3696135	total: 13.5s	remaining: 5.8s
# 699:	learn: 3.3671069	total: 13.5s	remaining: 5.78s
# 700:	learn: 3.3659514	total: 13.5s	remaining: 5.76s
# 701:	learn: 3.3650175	total: 13.5s	remaining: 5.74s
# 702:	learn: 3.3638183	total: 13.5s	remaining: 5.72s
# 703:	learn: 3.3626722	total: 13.6s	remaining: 5.7s
# 704:	learn: 3.3606172	total: 13.6s	remaining: 5.68s
# 705:	learn: 3.3595387	total: 13.6s	remaining: 5.66s
# 706:	learn: 3.3571603	total: 13.6s	remaining: 5.64s
# 707:	learn: 3.3560105	total: 13.6s	remaining: 5.63s
# 708:	learn: 3.3547814	total: 13.7s	remaining: 5.61s
# 709:	learn: 3.3527296	total: 13.7s	remaining: 5.59s
# 710:	learn: 3.3489419	total: 13.7s	remaining: 5.57s
# 711:	learn: 3.3479873	total: 13.7s	remaining: 5.55s
# 712:	learn: 3.3470632	total: 13.7s	remaining: 5.53s
# 713:	learn: 3.3462386	total: 13.8s	remaining: 5.51s
# 714:	learn: 3.3402360	total: 13.8s	remaining: 5.49s
# 715:	learn: 3.3391408	total: 13.8s	remaining: 5.47s
# 716:	learn: 3.3380923	total: 13.8s	remaining: 5.45s
# 717:	learn: 3.3361006	total: 13.8s	remaining: 5.43s
# 718:	learn: 3.3349786	total: 13.8s	remaining: 5.41s
# 719:	learn: 3.3339879	total: 13.9s	remaining: 5.39s
# 720:	learn: 3.3312746	total: 13.9s	remaining: 5.38s
# 721:	learn: 3.3289741	total: 13.9s	remaining: 5.36s
# 722:	learn: 3.3277098	total: 13.9s	remaining: 5.33s
# 723:	learn: 3.3267927	total: 13.9s	remaining: 5.32s
# 724:	learn: 3.3258565	total: 14s	remaining: 5.3s
# 725:	learn: 3.3228967	total: 14s	remaining: 5.28s
# 726:	learn: 3.3218740	total: 14s	remaining: 5.26s
# 727:	learn: 3.3208921	total: 14s	remaining: 5.24s
# 728:	learn: 3.3197881	total: 14.1s	remaining: 5.22s
# 729:	learn: 3.3188381	total: 14.1s	remaining: 5.2s
# 730:	learn: 3.3167398	total: 14.1s	remaining: 5.18s
# 731:	learn: 3.3142791	total: 14.1s	remaining: 5.17s
# 732:	learn: 3.3109066	total: 14.1s	remaining: 5.15s
# 733:	learn: 3.3098070	total: 14.2s	remaining: 5.13s
# 734:	learn: 3.3062484	total: 14.2s	remaining: 5.11s
# 735:	learn: 3.3052234	total: 14.2s	remaining: 5.09s
# 736:	learn: 3.3042981	total: 14.2s	remaining: 5.07s
# 737:	learn: 3.3035694	total: 14.2s	remaining: 5.05s
# 738:	learn: 3.3024971	total: 14.3s	remaining: 5.03s
# 739:	learn: 3.3014578	total: 14.3s	remaining: 5.01s
# 740:	learn: 3.3005480	total: 14.3s	remaining: 4.99s
# 741:	learn: 3.2973909	total: 14.3s	remaining: 4.97s
# 742:	learn: 3.2963584	total: 14.3s	remaining: 4.96s
# 743:	learn: 3.2951449	total: 14.3s	remaining: 4.94s
# 744:	learn: 3.2940606	total: 14.4s	remaining: 4.92s
# 745:	learn: 3.2930059	total: 14.4s	remaining: 4.9s
# 746:	learn: 3.2919383	total: 14.4s	remaining: 4.88s
# 747:	learn: 3.2910856	total: 14.4s	remaining: 4.86s
# 748:	learn: 3.2900809	total: 14.4s	remaining: 4.84s
# 749:	learn: 3.2892600	total: 14.5s	remaining: 4.82s
# 750:	learn: 3.2857254	total: 14.5s	remaining: 4.8s
# 751:	learn: 3.2829944	total: 14.5s	remaining: 4.78s
# 752:	learn: 3.2809050	total: 14.5s	remaining: 4.76s
# 753:	learn: 3.2799736	total: 14.5s	remaining: 4.74s
# 754:	learn: 3.2790057	total: 14.6s	remaining: 4.72s
# 755:	learn: 3.2779566	total: 14.6s	remaining: 4.7s
# 756:	learn: 3.2769822	total: 14.6s	remaining: 4.68s
# 757:	learn: 3.2752194	total: 14.6s	remaining: 4.67s
# 758:	learn: 3.2723303	total: 14.6s	remaining: 4.64s
# 759:	learn: 3.2692934	total: 14.6s	remaining: 4.63s
# 760:	learn: 3.2683780	total: 14.7s	remaining: 4.61s
# 761:	learn: 3.2673367	total: 14.7s	remaining: 4.59s
# 762:	learn: 3.2665700	total: 14.7s	remaining: 4.57s
# 763:	learn: 3.2655342	total: 14.7s	remaining: 4.55s
# 764:	learn: 3.2620924	total: 14.7s	remaining: 4.53s
# 765:	learn: 3.2577534	total: 14.8s	remaining: 4.51s
# 766:	learn: 3.2534803	total: 14.8s	remaining: 4.49s
# 767:	learn: 3.2523892	total: 14.8s	remaining: 4.47s
# 768:	learn: 3.2516563	total: 14.8s	remaining: 4.45s
# 769:	learn: 3.2487021	total: 14.8s	remaining: 4.43s
# 770:	learn: 3.2477914	total: 14.9s	remaining: 4.42s
# 771:	learn: 3.2453285	total: 14.9s	remaining: 4.4s
# 772:	learn: 3.2445837	total: 14.9s	remaining: 4.38s
# 773:	learn: 3.2435598	total: 14.9s	remaining: 4.36s
# 774:	learn: 3.2413906	total: 14.9s	remaining: 4.34s
# 775:	learn: 3.2393158	total: 15s	remaining: 4.32s
# 776:	learn: 3.2381895	total: 15s	remaining: 4.3s
# 777:	learn: 3.2372896	total: 15s	remaining: 4.28s
# 778:	learn: 3.2327814	total: 15s	remaining: 4.26s
# 779:	learn: 3.2319036	total: 15s	remaining: 4.24s
# 780:	learn: 3.2311786	total: 15.1s	remaining: 4.22s
# 781:	learn: 3.2291953	total: 15.1s	remaining: 4.2s
# 782:	learn: 3.2260307	total: 15.1s	remaining: 4.18s
# 783:	learn: 3.2252880	total: 15.1s	remaining: 4.16s
# 784:	learn: 3.2227703	total: 15.1s	remaining: 4.14s
# 785:	learn: 3.2219417	total: 15.1s	remaining: 4.12s
# 786:	learn: 3.2186333	total: 15.2s	remaining: 4.1s
# 787:	learn: 3.2160322	total: 15.2s	remaining: 4.08s
# 788:	learn: 3.2149770	total: 15.2s	remaining: 4.07s
# 789:	learn: 3.2140563	total: 15.2s	remaining: 4.04s
# 790:	learn: 3.2106461	total: 15.2s	remaining: 4.03s
# 791:	learn: 3.2057458	total: 15.3s	remaining: 4.01s
# 792:	learn: 3.2031834	total: 15.3s	remaining: 3.99s
# 793:	learn: 3.2022804	total: 15.3s	remaining: 3.97s
# 794:	learn: 3.2013045	total: 15.3s	remaining: 3.95s
# 795:	learn: 3.1990919	total: 15.3s	remaining: 3.93s
# 796:	learn: 3.1979231	total: 15.3s	remaining: 3.91s
# 797:	learn: 3.1953851	total: 15.4s	remaining: 3.89s
# 798:	learn: 3.1926024	total: 15.4s	remaining: 3.87s
# 799:	learn: 3.1914556	total: 15.4s	remaining: 3.85s
# 800:	learn: 3.1890414	total: 15.4s	remaining: 3.84s
# 801:	learn: 3.1882571	total: 15.5s	remaining: 3.82s
# 802:	learn: 3.1872925	total: 15.5s	remaining: 3.8s
# 803:	learn: 3.1850029	total: 15.5s	remaining: 3.78s
# 804:	learn: 3.1829172	total: 15.5s	remaining: 3.76s
# 805:	learn: 3.1808593	total: 15.5s	remaining: 3.74s
# 806:	learn: 3.1799701	total: 15.6s	remaining: 3.72s
# 807:	learn: 3.1790072	total: 15.6s	remaining: 3.7s
# 808:	learn: 3.1782420	total: 15.6s	remaining: 3.68s
# 809:	learn: 3.1771456	total: 15.6s	remaining: 3.66s
# 810:	learn: 3.1733474	total: 15.6s	remaining: 3.64s
# 811:	learn: 3.1723329	total: 15.7s	remaining: 3.62s
# 812:	learn: 3.1713894	total: 15.7s	remaining: 3.6s
# 813:	learn: 3.1704300	total: 15.7s	remaining: 3.58s
# 814:	learn: 3.1687605	total: 15.7s	remaining: 3.56s
# 815:	learn: 3.1658346	total: 15.7s	remaining: 3.55s
# 816:	learn: 3.1642042	total: 15.7s	remaining: 3.53s
# 817:	learn: 3.1632726	total: 15.8s	remaining: 3.51s
# 818:	learn: 3.1622311	total: 15.8s	remaining: 3.49s
# 819:	learn: 3.1613433	total: 15.8s	remaining: 3.47s
# 820:	learn: 3.1604024	total: 15.8s	remaining: 3.45s
# 821:	learn: 3.1595224	total: 15.9s	remaining: 3.43s
# 822:	learn: 3.1587024	total: 15.9s	remaining: 3.41s
# 823:	learn: 3.1568395	total: 15.9s	remaining: 3.39s
# 824:	learn: 3.1560174	total: 15.9s	remaining: 3.37s
# 825:	learn: 3.1536607	total: 15.9s	remaining: 3.35s
# 826:	learn: 3.1516116	total: 15.9s	remaining: 3.33s
# 827:	learn: 3.1504737	total: 16s	remaining: 3.32s
# 828:	learn: 3.1478959	total: 16s	remaining: 3.3s
# 829:	learn: 3.1460875	total: 16s	remaining: 3.28s
# 830:	learn: 3.1451508	total: 16s	remaining: 3.26s
# 831:	learn: 3.1416018	total: 16s	remaining: 3.24s
# 832:	learn: 3.1405622	total: 16.1s	remaining: 3.22s
# 833:	learn: 3.1382719	total: 16.1s	remaining: 3.2s
# 834:	learn: 3.1362896	total: 16.1s	remaining: 3.18s
# 835:	learn: 3.1354312	total: 16.1s	remaining: 3.16s
# 836:	learn: 3.1332054	total: 16.1s	remaining: 3.14s
# 837:	learn: 3.1309286	total: 16.1s	remaining: 3.12s
# 838:	learn: 3.1301070	total: 16.2s	remaining: 3.1s
# 839:	learn: 3.1291971	total: 16.2s	remaining: 3.08s
# 840:	learn: 3.1283073	total: 16.2s	remaining: 3.06s
# 841:	learn: 3.1273924	total: 16.2s	remaining: 3.04s
# 842:	learn: 3.1266669	total: 16.2s	remaining: 3.02s
# 843:	learn: 3.1257086	total: 16.3s	remaining: 3s
# 844:	learn: 3.1248558	total: 16.3s	remaining: 2.98s
# 845:	learn: 3.1208783	total: 16.3s	remaining: 2.96s
# 846:	learn: 3.1186956	total: 16.3s	remaining: 2.95s
# 847:	learn: 3.1177296	total: 16.3s	remaining: 2.93s
# 848:	learn: 3.1159438	total: 16.4s	remaining: 2.91s
# 849:	learn: 3.1134297	total: 16.4s	remaining: 2.89s
# 850:	learn: 3.1103196	total: 16.4s	remaining: 2.87s
# 851:	learn: 3.1083965	total: 16.4s	remaining: 2.85s
# 852:	learn: 3.1060036	total: 16.4s	remaining: 2.83s
# 853:	learn: 3.1051206	total: 16.5s	remaining: 2.81s
# 854:	learn: 3.1042626	total: 16.5s	remaining: 2.79s
# 855:	learn: 3.1024847	total: 16.5s	remaining: 2.77s
# 856:	learn: 3.1015059	total: 16.5s	remaining: 2.75s
# 857:	learn: 3.1005645	total: 16.5s	remaining: 2.73s
# 858:	learn: 3.0997594	total: 16.5s	remaining: 2.72s
# 859:	learn: 3.0990441	total: 16.6s	remaining: 2.7s
# 860:	learn: 3.0982445	total: 16.6s	remaining: 2.68s
# 861:	learn: 3.0964979	total: 16.6s	remaining: 2.66s
# 862:	learn: 3.0957404	total: 16.6s	remaining: 2.64s
# 863:	learn: 3.0949754	total: 16.6s	remaining: 2.62s
# 864:	learn: 3.0929598	total: 16.7s	remaining: 2.6s
# 865:	learn: 3.0906922	total: 16.7s	remaining: 2.58s
# 866:	learn: 3.0899557	total: 16.7s	remaining: 2.56s
# 867:	learn: 3.0890756	total: 16.7s	remaining: 2.54s
# 868:	learn: 3.0881895	total: 16.7s	remaining: 2.52s
# 869:	learn: 3.0876320	total: 16.7s	remaining: 2.5s
# 870:	learn: 3.0859604	total: 16.8s	remaining: 2.48s
# 871:	learn: 3.0849630	total: 16.8s	remaining: 2.46s
# 872:	learn: 3.0830788	total: 16.8s	remaining: 2.44s
# 873:	learn: 3.0821861	total: 16.8s	remaining: 2.42s
# 874:	learn: 3.0790216	total: 16.8s	remaining: 2.4s
# 875:	learn: 3.0781413	total: 16.9s	remaining: 2.39s
# 876:	learn: 3.0763376	total: 16.9s	remaining: 2.37s
# 877:	learn: 3.0754363	total: 16.9s	remaining: 2.35s
# 878:	learn: 3.0746446	total: 16.9s	remaining: 2.33s
# 879:	learn: 3.0716485	total: 16.9s	remaining: 2.31s
# 880:	learn: 3.0708537	total: 16.9s	remaining: 2.29s
# 881:	learn: 3.0687381	total: 17s	remaining: 2.27s
# 882:	learn: 3.0678386	total: 17s	remaining: 2.25s
# 883:	learn: 3.0670391	total: 17s	remaining: 2.23s
# 884:	learn: 3.0657684	total: 17s	remaining: 2.21s
# 885:	learn: 3.0642055	total: 17s	remaining: 2.19s
# 886:	learn: 3.0632292	total: 17.1s	remaining: 2.17s
# 887:	learn: 3.0613447	total: 17.1s	remaining: 2.15s
# 888:	learn: 3.0604839	total: 17.1s	remaining: 2.13s
# 889:	learn: 3.0569760	total: 17.1s	remaining: 2.11s
# 890:	learn: 3.0563034	total: 17.1s	remaining: 2.1s
# 891:	learn: 3.0544833	total: 17.1s	remaining: 2.08s
# 892:	learn: 3.0523938	total: 17.2s	remaining: 2.06s
# 893:	learn: 3.0515569	total: 17.2s	remaining: 2.04s
# 894:	learn: 3.0496350	total: 17.2s	remaining: 2.02s
# 895:	learn: 3.0470074	total: 17.2s	remaining: 2s
# 896:	learn: 3.0457015	total: 17.2s	remaining: 1.98s
# 897:	learn: 3.0430447	total: 17.3s	remaining: 1.96s
# 898:	learn: 3.0405962	total: 17.3s	remaining: 1.94s
# 899:	learn: 3.0380515	total: 17.3s	remaining: 1.92s
# 900:	learn: 3.0359066	total: 17.3s	remaining: 1.9s
# 901:	learn: 3.0350473	total: 17.3s	remaining: 1.88s
# 902:	learn: 3.0342302	total: 17.4s	remaining: 1.86s
# 903:	learn: 3.0322801	total: 17.4s	remaining: 1.84s
# 904:	learn: 3.0299708	total: 17.4s	remaining: 1.82s
# 905:	learn: 3.0280246	total: 17.4s	remaining: 1.81s
# 906:	learn: 3.0253243	total: 17.4s	remaining: 1.79s
# 907:	learn: 3.0225750	total: 17.4s	remaining: 1.77s
# 908:	learn: 3.0215338	total: 17.5s	remaining: 1.75s
# 909:	learn: 3.0197012	total: 17.5s	remaining: 1.73s
# 910:	learn: 3.0175361	total: 17.5s	remaining: 1.71s
# 911:	learn: 3.0148962	total: 17.5s	remaining: 1.69s
# 912:	learn: 3.0140171	total: 17.5s	remaining: 1.67s
# 913:	learn: 3.0115885	total: 17.6s	remaining: 1.65s
# 914:	learn: 3.0108405	total: 17.6s	remaining: 1.63s
# 915:	learn: 3.0082638	total: 17.6s	remaining: 1.61s
# 916:	learn: 3.0066081	total: 17.6s	remaining: 1.59s
# 917:	learn: 3.0037911	total: 17.6s	remaining: 1.57s
# 918:	learn: 3.0029977	total: 17.7s	remaining: 1.56s
# 919:	learn: 3.0021482	total: 17.7s	remaining: 1.54s
# 920:	learn: 3.0013033	total: 17.7s	remaining: 1.52s
# 921:	learn: 2.9992894	total: 17.7s	remaining: 1.5s
# 922:	learn: 2.9984311	total: 17.7s	remaining: 1.48s
# 923:	learn: 2.9969870	total: 17.7s	remaining: 1.46s
# 924:	learn: 2.9962122	total: 17.8s	remaining: 1.44s
# 925:	learn: 2.9946959	total: 17.8s	remaining: 1.42s
# 926:	learn: 2.9931535	total: 17.8s	remaining: 1.4s
# 927:	learn: 2.9924013	total: 17.8s	remaining: 1.38s
# 928:	learn: 2.9916479	total: 17.8s	remaining: 1.36s
# 929:	learn: 2.9901244	total: 17.9s	remaining: 1.34s
# 930:	learn: 2.9891197	total: 17.9s	remaining: 1.32s
# 931:	learn: 2.9874543	total: 17.9s	remaining: 1.3s
# 932:	learn: 2.9866256	total: 17.9s	remaining: 1.29s
# 933:	learn: 2.9852836	total: 17.9s	remaining: 1.27s
# 934:	learn: 2.9845374	total: 18s	remaining: 1.25s
# 935:	learn: 2.9836521	total: 18s	remaining: 1.23s
# 936:	learn: 2.9814360	total: 18s	remaining: 1.21s
# 937:	learn: 2.9797130	total: 18s	remaining: 1.19s
# 938:	learn: 2.9782923	total: 18s	remaining: 1.17s
# 939:	learn: 2.9775779	total: 18.1s	remaining: 1.15s
# 940:	learn: 2.9751496	total: 18.1s	remaining: 1.13s
# 941:	learn: 2.9734260	total: 18.1s	remaining: 1.11s
# 942:	learn: 2.9711224	total: 18.1s	remaining: 1.09s
# 943:	learn: 2.9703904	total: 18.1s	remaining: 1.07s
# 944:	learn: 2.9685226	total: 18.1s	remaining: 1.06s
# 945:	learn: 2.9666211	total: 18.2s	remaining: 1.04s
# 946:	learn: 2.9630615	total: 18.2s	remaining: 1.02s
# 947:	learn: 2.9620372	total: 18.2s	remaining: 999ms
# 948:	learn: 2.9613323	total: 18.2s	remaining: 979ms
# 949:	learn: 2.9606389	total: 18.2s	remaining: 960ms
# 950:	learn: 2.9599226	total: 18.3s	remaining: 941ms
# 951:	learn: 2.9575381	total: 18.3s	remaining: 922ms
# 952:	learn: 2.9557733	total: 18.3s	remaining: 903ms
# 953:	learn: 2.9551168	total: 18.3s	remaining: 884ms
# 954:	learn: 2.9541379	total: 18.3s	remaining: 864ms
# 955:	learn: 2.9521448	total: 18.4s	remaining: 845ms
# 956:	learn: 2.9502633	total: 18.4s	remaining: 826ms
# 957:	learn: 2.9494715	total: 18.4s	remaining: 807ms
# 958:	learn: 2.9486637	total: 18.4s	remaining: 787ms
# 959:	learn: 2.9478611	total: 18.4s	remaining: 768ms
# 960:	learn: 2.9471470	total: 18.4s	remaining: 749ms
# 961:	learn: 2.9442654	total: 18.5s	remaining: 730ms
# 962:	learn: 2.9432715	total: 18.5s	remaining: 711ms
# 963:	learn: 2.9425091	total: 18.5s	remaining: 691ms
# 964:	learn: 2.9414970	total: 18.5s	remaining: 672ms
# 965:	learn: 2.9407694	total: 18.5s	remaining: 653ms
# 966:	learn: 2.9392880	total: 18.6s	remaining: 634ms
# 967:	learn: 2.9385639	total: 18.6s	remaining: 614ms
# 968:	learn: 2.9365257	total: 18.6s	remaining: 595ms
# 969:	learn: 2.9358621	total: 18.6s	remaining: 576ms
# 970:	learn: 2.9351877	total: 18.6s	remaining: 557ms
# 971:	learn: 2.9345033	total: 18.7s	remaining: 538ms
# 972:	learn: 2.9338145	total: 18.7s	remaining: 518ms
# 973:	learn: 2.9329928	total: 18.7s	remaining: 499ms
# 974:	learn: 2.9322946	total: 18.7s	remaining: 480ms
# 975:	learn: 2.9302711	total: 18.7s	remaining: 461ms
# 976:	learn: 2.9295316	total: 18.7s	remaining: 441ms
# 977:	learn: 2.9267784	total: 18.8s	remaining: 422ms
# 978:	learn: 2.9218663	total: 18.8s	remaining: 403ms
# 979:	learn: 2.9194359	total: 18.8s	remaining: 384ms
# 980:	learn: 2.9186685	total: 18.8s	remaining: 365ms
# 981:	learn: 2.9171746	total: 18.9s	remaining: 346ms
# 982:	learn: 2.9165126	total: 18.9s	remaining: 326ms
# 983:	learn: 2.9154535	total: 18.9s	remaining: 307ms
# 984:	learn: 2.9147754	total: 18.9s	remaining: 288ms
# 985:	learn: 2.9140172	total: 18.9s	remaining: 269ms
# 986:	learn: 2.9124259	total: 18.9s	remaining: 249ms
# 987:	learn: 2.9109664	total: 19s	remaining: 230ms
# 988:	learn: 2.9102588	total: 19s	remaining: 211ms
# 989:	learn: 2.9096216	total: 19s	remaining: 192ms
# 990:	learn: 2.9089977	total: 19s	remaining: 173ms
# 991:	learn: 2.9083544	total: 19s	remaining: 154ms
# 992:	learn: 2.9052434	total: 19.1s	remaining: 134ms
# 993:	learn: 2.9047351	total: 19.1s	remaining: 115ms
# 994:	learn: 2.9040234	total: 19.1s	remaining: 95.9ms
# 995:	learn: 2.9025794	total: 19.1s	remaining: 76.8ms
# 996:	learn: 2.8993970	total: 19.1s	remaining: 57.6ms
# 997:	learn: 2.8988193	total: 19.2s	remaining: 38.4ms
# 998:	learn: 2.8959559	total: 19.2s	remaining: 19.2ms
# 999:	learn: 2.8943269	total: 19.2s	remaining: 0us
# <catboost.core.CatBoostRegressor object at 0x7f78d6894970>
# 3.811659175054392 2.3031921382709273

# %%
model5.fit(X_tr_orig, y_tr_orig)
y_pred = model5.predict(X_test)

submission_prep(y_pred, './data/test_Offer_ID_map_category_ct.json', 2)
# Out:
# 0:	learn: 6.1985637	total: 24.4ms	remaining: 24.4s
# 1:	learn: 6.1645846	total: 44.2ms	remaining: 22.1s
# 2:	learn: 6.1333526	total: 65.2ms	remaining: 21.7s
# 3:	learn: 6.1075089	total: 85.4ms	remaining: 21.3s
# 4:	learn: 6.0826778	total: 106ms	remaining: 21.2s
# 5:	learn: 6.0595746	total: 127ms	remaining: 21.1s
# 6:	learn: 6.0438931	total: 147ms	remaining: 20.9s
# 7:	learn: 6.0262608	total: 167ms	remaining: 20.8s
# 8:	learn: 6.0030375	total: 188ms	remaining: 20.7s
# 9:	learn: 5.9781764	total: 208ms	remaining: 20.6s
# 10:	learn: 5.9636929	total: 227ms	remaining: 20.4s
# 11:	learn: 5.9429969	total: 246ms	remaining: 20.3s
# 12:	learn: 5.9199570	total: 266ms	remaining: 20.2s
# 13:	learn: 5.9052667	total: 285ms	remaining: 20.1s
# 14:	learn: 5.8885325	total: 305ms	remaining: 20s
# 15:	learn: 5.8748040	total: 325ms	remaining: 20s
# 16:	learn: 5.8617744	total: 344ms	remaining: 19.9s
# 17:	learn: 5.8462742	total: 363ms	remaining: 19.8s
# 18:	learn: 5.8284631	total: 382ms	remaining: 19.7s
# 19:	learn: 5.8109545	total: 401ms	remaining: 19.6s
# 20:	learn: 5.7962575	total: 419ms	remaining: 19.5s
# 21:	learn: 5.7809958	total: 439ms	remaining: 19.5s
# 22:	learn: 5.7697364	total: 458ms	remaining: 19.5s
# 23:	learn: 5.7584303	total: 477ms	remaining: 19.4s
# 24:	learn: 5.7485333	total: 495ms	remaining: 19.3s
# 25:	learn: 5.7340391	total: 514ms	remaining: 19.3s
# 26:	learn: 5.7212220	total: 534ms	remaining: 19.2s
# 27:	learn: 5.7101032	total: 558ms	remaining: 19.4s
# 28:	learn: 5.6954730	total: 577ms	remaining: 19.3s
# 29:	learn: 5.6923984	total: 596ms	remaining: 19.3s
# 30:	learn: 5.6903539	total: 617ms	remaining: 19.3s
# 31:	learn: 5.6874072	total: 638ms	remaining: 19.3s
# 32:	learn: 5.6771915	total: 658ms	remaining: 19.3s
# 33:	learn: 5.6656782	total: 681ms	remaining: 19.3s
# 34:	learn: 5.6572135	total: 702ms	remaining: 19.4s
# 35:	learn: 5.6466208	total: 725ms	remaining: 19.4s
# 36:	learn: 5.6348523	total: 749ms	remaining: 19.5s
# 37:	learn: 5.6327520	total: 773ms	remaining: 19.6s
# 38:	learn: 5.6235300	total: 793ms	remaining: 19.5s
# 39:	learn: 5.6207823	total: 813ms	remaining: 19.5s
# 40:	learn: 5.6109343	total: 834ms	remaining: 19.5s
# 41:	learn: 5.6053000	total: 855ms	remaining: 19.5s
# 42:	learn: 5.5950530	total: 881ms	remaining: 19.6s
# 43:	learn: 5.5836961	total: 902ms	remaining: 19.6s
# 44:	learn: 5.5810078	total: 921ms	remaining: 19.6s
# 45:	learn: 5.5691693	total: 943ms	remaining: 19.6s
# 46:	learn: 5.5605960	total: 962ms	remaining: 19.5s
# 47:	learn: 5.5560118	total: 984ms	remaining: 19.5s
# 48:	learn: 5.5535333	total: 1s	remaining: 19.5s
# 49:	learn: 5.5446969	total: 1.02s	remaining: 19.5s
# 50:	learn: 5.5411726	total: 1.04s	remaining: 19.4s
# 51:	learn: 5.5368384	total: 1.06s	remaining: 19.4s
# 52:	learn: 5.5309422	total: 1.08s	remaining: 19.3s
# 53:	learn: 5.5237712	total: 1.1s	remaining: 19.2s
# 54:	learn: 5.5219684	total: 1.12s	remaining: 19.2s
# 55:	learn: 5.5163675	total: 1.14s	remaining: 19.1s
# 56:	learn: 5.5125617	total: 1.16s	remaining: 19.1s
# 57:	learn: 5.5081822	total: 1.18s	remaining: 19.1s
# 58:	learn: 5.4994331	total: 1.19s	remaining: 19.1s
# 59:	learn: 5.4904309	total: 1.22s	remaining: 19s
# 60:	learn: 5.4876504	total: 1.24s	remaining: 19s
# 61:	learn: 5.4798954	total: 1.25s	remaining: 19s
# 62:	learn: 5.4776618	total: 1.28s	remaining: 19s
# 63:	learn: 5.4730394	total: 1.3s	remaining: 19s
# 64:	learn: 5.4682867	total: 1.31s	remaining: 18.9s
# 65:	learn: 5.4657565	total: 1.34s	remaining: 18.9s
# 66:	learn: 5.4612584	total: 1.36s	remaining: 18.9s
# 67:	learn: 5.4587684	total: 1.38s	remaining: 18.9s
# 68:	learn: 5.4555844	total: 1.4s	remaining: 18.9s
# 69:	learn: 5.4468687	total: 1.42s	remaining: 18.9s
# 70:	learn: 5.4433380	total: 1.44s	remaining: 18.9s
# 71:	learn: 5.4418938	total: 1.47s	remaining: 18.9s
# 72:	learn: 5.4389364	total: 1.49s	remaining: 18.9s
# 73:	learn: 5.4295571	total: 1.51s	remaining: 18.8s
# 74:	learn: 5.4269490	total: 1.53s	remaining: 18.8s
# 75:	learn: 5.4228393	total: 1.54s	remaining: 18.8s
# 76:	learn: 5.4158767	total: 1.56s	remaining: 18.8s
# 77:	learn: 5.4049485	total: 1.58s	remaining: 18.7s
# 78:	learn: 5.4001640	total: 1.6s	remaining: 18.7s
# 79:	learn: 5.3929558	total: 1.62s	remaining: 18.7s
# 80:	learn: 5.3870668	total: 1.65s	remaining: 18.7s
# 81:	learn: 5.3772593	total: 1.67s	remaining: 18.6s
# 82:	learn: 5.3746016	total: 1.69s	remaining: 18.6s
# 83:	learn: 5.3714603	total: 1.71s	remaining: 18.6s
# 84:	learn: 5.3678477	total: 1.73s	remaining: 18.6s
# 85:	learn: 5.3654969	total: 1.75s	remaining: 18.6s
# 86:	learn: 5.3614719	total: 1.77s	remaining: 18.5s
# 87:	learn: 5.3567554	total: 1.78s	remaining: 18.5s
# 88:	learn: 5.3538182	total: 1.8s	remaining: 18.5s
# 89:	learn: 5.3511831	total: 1.82s	remaining: 18.4s
# 90:	learn: 5.3464332	total: 1.84s	remaining: 18.4s
# 91:	learn: 5.3393559	total: 1.86s	remaining: 18.4s
# 92:	learn: 5.3368924	total: 1.88s	remaining: 18.4s
# 93:	learn: 5.3340173	total: 1.9s	remaining: 18.3s
# 94:	learn: 5.3277537	total: 1.92s	remaining: 18.3s
# 95:	learn: 5.3237819	total: 1.94s	remaining: 18.3s
# 96:	learn: 5.3186848	total: 1.97s	remaining: 18.3s
# 97:	learn: 5.3139015	total: 1.99s	remaining: 18.3s
# 98:	learn: 5.3116692	total: 2.01s	remaining: 18.3s
# 99:	learn: 5.3052317	total: 2.03s	remaining: 18.3s
# 100:	learn: 5.3018025	total: 2.05s	remaining: 18.2s
# 101:	learn: 5.2983043	total: 2.07s	remaining: 18.2s
# 102:	learn: 5.2962560	total: 2.09s	remaining: 18.2s
# 103:	learn: 5.2941666	total: 2.11s	remaining: 18.2s
# 104:	learn: 5.2917637	total: 2.13s	remaining: 18.1s
# 105:	learn: 5.2887655	total: 2.15s	remaining: 18.1s
# 106:	learn: 5.2864051	total: 2.17s	remaining: 18.1s
# 107:	learn: 5.2821112	total: 2.18s	remaining: 18s
# 108:	learn: 5.2805016	total: 2.2s	remaining: 18s
# 109:	learn: 5.2769622	total: 2.22s	remaining: 18s
# 110:	learn: 5.2736438	total: 2.25s	remaining: 18s
# 111:	learn: 5.2703890	total: 2.27s	remaining: 18s
# 112:	learn: 5.2641474	total: 2.28s	remaining: 17.9s
# 113:	learn: 5.2576125	total: 2.3s	remaining: 17.9s
# 114:	learn: 5.2542405	total: 2.32s	remaining: 17.9s
# 115:	learn: 5.2488778	total: 2.34s	remaining: 17.9s
# 116:	learn: 5.2439690	total: 2.37s	remaining: 17.9s
# 117:	learn: 5.2409302	total: 2.38s	remaining: 17.8s
# 118:	learn: 5.2381641	total: 2.4s	remaining: 17.8s
# 119:	learn: 5.2365307	total: 2.42s	remaining: 17.8s
# 120:	learn: 5.2280035	total: 2.44s	remaining: 17.8s
# 121:	learn: 5.2250140	total: 2.46s	remaining: 17.7s
# 122:	learn: 5.2228791	total: 2.48s	remaining: 17.7s
# 123:	learn: 5.2198584	total: 2.51s	remaining: 17.7s
# 124:	learn: 5.2177766	total: 2.52s	remaining: 17.7s
# 125:	learn: 5.2126237	total: 2.54s	remaining: 17.6s
# 126:	learn: 5.2111588	total: 2.56s	remaining: 17.6s
# 127:	learn: 5.2083889	total: 2.59s	remaining: 17.6s
# 128:	learn: 5.2017590	total: 2.61s	remaining: 17.6s
# 129:	learn: 5.1983648	total: 2.62s	remaining: 17.6s
# 130:	learn: 5.1931094	total: 2.64s	remaining: 17.5s
# 131:	learn: 5.1885167	total: 2.66s	remaining: 17.5s
# 132:	learn: 5.1863842	total: 2.68s	remaining: 17.5s
# 133:	learn: 5.1829842	total: 2.7s	remaining: 17.4s
# 134:	learn: 5.1788210	total: 2.72s	remaining: 17.4s
# 135:	learn: 5.1753477	total: 2.74s	remaining: 17.4s
# 136:	learn: 5.1736159	total: 2.76s	remaining: 17.4s
# 137:	learn: 5.1707731	total: 2.78s	remaining: 17.4s
# 138:	learn: 5.1640597	total: 2.8s	remaining: 17.4s
# 139:	learn: 5.1590634	total: 2.82s	remaining: 17.3s
# 140:	learn: 5.1570257	total: 2.84s	remaining: 17.3s
# 141:	learn: 5.1535170	total: 2.86s	remaining: 17.3s
# 142:	learn: 5.1503518	total: 2.88s	remaining: 17.3s
# 143:	learn: 5.1485042	total: 2.9s	remaining: 17.3s
# 144:	learn: 5.1469928	total: 2.92s	remaining: 17.2s
# 145:	learn: 5.1456250	total: 2.94s	remaining: 17.2s
# 146:	learn: 5.1430872	total: 2.96s	remaining: 17.2s
# 147:	learn: 5.1416705	total: 2.99s	remaining: 17.2s
# 148:	learn: 5.1384535	total: 3.01s	remaining: 17.2s
# 149:	learn: 5.1351884	total: 3.03s	remaining: 17.2s
# 150:	learn: 5.1320202	total: 3.05s	remaining: 17.1s
# 151:	learn: 5.1296477	total: 3.07s	remaining: 17.1s
# 152:	learn: 5.1274732	total: 3.1s	remaining: 17.1s
# 153:	learn: 5.1255673	total: 3.12s	remaining: 17.1s
# 154:	learn: 5.1212649	total: 3.13s	remaining: 17.1s
# 155:	learn: 5.1173476	total: 3.16s	remaining: 17.1s
# 156:	learn: 5.1124306	total: 3.19s	remaining: 17.1s
# 157:	learn: 5.1110117	total: 3.21s	remaining: 17.1s
# 158:	learn: 5.1090633	total: 3.23s	remaining: 17.1s
# 159:	learn: 5.1068177	total: 3.25s	remaining: 17s
# 160:	learn: 5.1037408	total: 3.27s	remaining: 17s
# 161:	learn: 5.1013472	total: 3.29s	remaining: 17s
# 162:	learn: 5.0992660	total: 3.31s	remaining: 17s
# 163:	learn: 5.0976689	total: 3.33s	remaining: 17s
# 164:	learn: 5.0932590	total: 3.35s	remaining: 16.9s
# 165:	learn: 5.0887275	total: 3.37s	remaining: 16.9s
# 166:	learn: 5.0872006	total: 3.38s	remaining: 16.9s
# 167:	learn: 5.0845746	total: 3.4s	remaining: 16.9s
# 168:	learn: 5.0829105	total: 3.42s	remaining: 16.8s
# 169:	learn: 5.0783074	total: 3.44s	remaining: 16.8s
# 170:	learn: 5.0760812	total: 3.46s	remaining: 16.8s
# 171:	learn: 5.0722396	total: 3.48s	remaining: 16.8s
# 172:	learn: 5.0693403	total: 3.5s	remaining: 16.7s
# 173:	learn: 5.0665436	total: 3.52s	remaining: 16.7s
# 174:	learn: 5.0644848	total: 3.54s	remaining: 16.7s
# 175:	learn: 5.0616726	total: 3.56s	remaining: 16.7s
# 176:	learn: 5.0592746	total: 3.58s	remaining: 16.6s
# 177:	learn: 5.0547600	total: 3.6s	remaining: 16.6s
# 178:	learn: 5.0526433	total: 3.62s	remaining: 16.6s
# 179:	learn: 5.0445480	total: 3.64s	remaining: 16.6s
# 180:	learn: 5.0422819	total: 3.65s	remaining: 16.5s
# 181:	learn: 5.0383196	total: 3.67s	remaining: 16.5s
# 182:	learn: 5.0343657	total: 3.69s	remaining: 16.5s
# 183:	learn: 5.0317262	total: 3.72s	remaining: 16.5s
# 184:	learn: 5.0254865	total: 3.74s	remaining: 16.5s
# 185:	learn: 5.0238493	total: 3.76s	remaining: 16.4s
# 186:	learn: 5.0210393	total: 3.78s	remaining: 16.4s
# 187:	learn: 5.0200761	total: 3.8s	remaining: 16.4s
# 188:	learn: 5.0161664	total: 3.82s	remaining: 16.4s
# 189:	learn: 5.0142783	total: 3.83s	remaining: 16.4s
# 190:	learn: 5.0093874	total: 3.85s	remaining: 16.3s
# 191:	learn: 5.0061474	total: 3.87s	remaining: 16.3s
# 192:	learn: 5.0028264	total: 3.89s	remaining: 16.3s
# 193:	learn: 5.0010179	total: 3.91s	remaining: 16.2s
# 194:	learn: 4.9981498	total: 3.93s	remaining: 16.2s
# 195:	learn: 4.9947363	total: 3.95s	remaining: 16.2s
# 196:	learn: 4.9926126	total: 3.97s	remaining: 16.2s
# 197:	learn: 4.9890307	total: 3.99s	remaining: 16.2s
# 198:	learn: 4.9845709	total: 4.01s	remaining: 16.1s
# 199:	learn: 4.9810137	total: 4.03s	remaining: 16.1s
# 200:	learn: 4.9789903	total: 4.05s	remaining: 16.1s
# 201:	learn: 4.9760657	total: 4.07s	remaining: 16.1s
# 202:	learn: 4.9735997	total: 4.09s	remaining: 16s
# 203:	learn: 4.9717846	total: 4.11s	remaining: 16s
# 204:	learn: 4.9692606	total: 4.12s	remaining: 16s
# 205:	learn: 4.9633643	total: 4.14s	remaining: 16s
# 206:	learn: 4.9609326	total: 4.17s	remaining: 16s
# 207:	learn: 4.9528707	total: 4.19s	remaining: 15.9s
# 208:	learn: 4.9490691	total: 4.21s	remaining: 15.9s
# 209:	learn: 4.9459882	total: 4.23s	remaining: 15.9s
# 210:	learn: 4.9434440	total: 4.25s	remaining: 15.9s
# 211:	learn: 4.9409278	total: 4.27s	remaining: 15.9s
# 212:	learn: 4.9351542	total: 4.29s	remaining: 15.8s
# 213:	learn: 4.9324249	total: 4.3s	remaining: 15.8s
# 214:	learn: 4.9284495	total: 4.33s	remaining: 15.8s
# 215:	learn: 4.9263063	total: 4.34s	remaining: 15.8s
# 216:	learn: 4.9201771	total: 4.37s	remaining: 15.8s
# 217:	learn: 4.9175680	total: 4.38s	remaining: 15.7s
# 218:	learn: 4.9135665	total: 4.4s	remaining: 15.7s
# 219:	learn: 4.9073535	total: 4.42s	remaining: 15.7s
# 220:	learn: 4.9024882	total: 4.44s	remaining: 15.7s
# 221:	learn: 4.8920445	total: 4.46s	remaining: 15.6s
# 222:	learn: 4.8897814	total: 4.48s	remaining: 15.6s
# 223:	learn: 4.8862987	total: 4.5s	remaining: 15.6s
# 224:	learn: 4.8836967	total: 4.52s	remaining: 15.6s
# 225:	learn: 4.8810114	total: 4.54s	remaining: 15.5s
# 226:	learn: 4.8756619	total: 4.56s	remaining: 15.5s
# 227:	learn: 4.8729941	total: 4.58s	remaining: 15.5s
# 228:	learn: 4.8707283	total: 4.6s	remaining: 15.5s
# 229:	learn: 4.8690194	total: 4.62s	remaining: 15.5s
# 230:	learn: 4.8653738	total: 4.63s	remaining: 15.4s
# 231:	learn: 4.8631498	total: 4.65s	remaining: 15.4s
# 232:	learn: 4.8603198	total: 4.67s	remaining: 15.4s
# 233:	learn: 4.8554008	total: 4.7s	remaining: 15.4s
# 234:	learn: 4.8527055	total: 4.71s	remaining: 15.3s
# 235:	learn: 4.8503868	total: 4.73s	remaining: 15.3s
# 236:	learn: 4.8479243	total: 4.75s	remaining: 15.3s
# 237:	learn: 4.8455671	total: 4.77s	remaining: 15.3s
# 238:	learn: 4.8430485	total: 4.79s	remaining: 15.3s
# 239:	learn: 4.8407350	total: 4.81s	remaining: 15.2s
# 240:	learn: 4.8385689	total: 4.83s	remaining: 15.2s
# 241:	learn: 4.8318952	total: 4.85s	remaining: 15.2s
# 242:	learn: 4.8249389	total: 4.87s	remaining: 15.2s
# 243:	learn: 4.8232668	total: 4.89s	remaining: 15.2s
# 244:	learn: 4.8175230	total: 4.91s	remaining: 15.1s
# 245:	learn: 4.8128220	total: 4.93s	remaining: 15.1s
# 246:	learn: 4.8103755	total: 4.95s	remaining: 15.1s
# 247:	learn: 4.8061474	total: 4.96s	remaining: 15.1s
# 248:	learn: 4.8000490	total: 4.99s	remaining: 15s
# 249:	learn: 4.7964036	total: 5.01s	remaining: 15s
# 250:	learn: 4.7944167	total: 5.03s	remaining: 15s
# 251:	learn: 4.7865181	total: 5.05s	remaining: 15s
# 252:	learn: 4.7842543	total: 5.07s	remaining: 15s
# 253:	learn: 4.7817870	total: 5.09s	remaining: 14.9s
# 254:	learn: 4.7782436	total: 5.11s	remaining: 14.9s
# 255:	learn: 4.7733972	total: 5.13s	remaining: 14.9s
# 256:	learn: 4.7705654	total: 5.15s	remaining: 14.9s
# 257:	learn: 4.7675124	total: 5.17s	remaining: 14.9s
# 258:	learn: 4.7599257	total: 5.18s	remaining: 14.8s
# 259:	learn: 4.7541240	total: 5.2s	remaining: 14.8s
# 260:	learn: 4.7516659	total: 5.22s	remaining: 14.8s
# 261:	learn: 4.7467745	total: 5.24s	remaining: 14.8s
# 262:	learn: 4.7434509	total: 5.26s	remaining: 14.7s
# 263:	learn: 4.7395154	total: 5.28s	remaining: 14.7s
# 264:	learn: 4.7371324	total: 5.3s	remaining: 14.7s
# 265:	learn: 4.7348136	total: 5.32s	remaining: 14.7s
# 266:	learn: 4.7306879	total: 5.34s	remaining: 14.6s
# 267:	learn: 4.7260941	total: 5.36s	remaining: 14.6s
# 268:	learn: 4.7219941	total: 5.38s	remaining: 14.6s
# 269:	learn: 4.7196657	total: 5.39s	remaining: 14.6s
# 270:	learn: 4.7175574	total: 5.41s	remaining: 14.6s
# 271:	learn: 4.7153087	total: 5.43s	remaining: 14.5s
# 272:	learn: 4.7079970	total: 5.45s	remaining: 14.5s
# 273:	learn: 4.7058189	total: 5.47s	remaining: 14.5s
# 274:	learn: 4.7021010	total: 5.49s	remaining: 14.5s
# 275:	learn: 4.6997548	total: 5.51s	remaining: 14.5s
# 276:	learn: 4.6924924	total: 5.53s	remaining: 14.4s
# 277:	learn: 4.6867147	total: 5.55s	remaining: 14.4s
# 278:	learn: 4.6838307	total: 5.57s	remaining: 14.4s
# 279:	learn: 4.6779379	total: 5.59s	remaining: 14.4s
# 280:	learn: 4.6755174	total: 5.61s	remaining: 14.4s
# 281:	learn: 4.6723828	total: 5.63s	remaining: 14.3s
# 282:	learn: 4.6690865	total: 5.65s	remaining: 14.3s
# 283:	learn: 4.6668927	total: 5.67s	remaining: 14.3s
# 284:	learn: 4.6647227	total: 5.69s	remaining: 14.3s
# 285:	learn: 4.6597763	total: 5.71s	remaining: 14.2s
# 286:	learn: 4.6562162	total: 5.73s	remaining: 14.2s
# 287:	learn: 4.6475764	total: 5.75s	remaining: 14.2s
# 288:	learn: 4.6452754	total: 5.77s	remaining: 14.2s
# 289:	learn: 4.6369337	total: 5.78s	remaining: 14.2s
# 290:	learn: 4.6347615	total: 5.8s	remaining: 14.1s
# 291:	learn: 4.6276916	total: 5.82s	remaining: 14.1s
# 292:	learn: 4.6255804	total: 5.84s	remaining: 14.1s
# 293:	learn: 4.6196382	total: 5.87s	remaining: 14.1s
# 294:	learn: 4.6121742	total: 5.89s	remaining: 14.1s
# 295:	learn: 4.6071612	total: 5.91s	remaining: 14.1s
# 296:	learn: 4.6038158	total: 5.93s	remaining: 14s
# 297:	learn: 4.6018669	total: 5.96s	remaining: 14s
# 298:	learn: 4.5998042	total: 5.97s	remaining: 14s
# 299:	learn: 4.5967420	total: 5.99s	remaining: 14s
# 300:	learn: 4.5949469	total: 6.03s	remaining: 14s
# 301:	learn: 4.5921051	total: 6.05s	remaining: 14s
# 302:	learn: 4.5902129	total: 6.07s	remaining: 14s
# 303:	learn: 4.5857450	total: 6.09s	remaining: 13.9s
# 304:	learn: 4.5837404	total: 6.11s	remaining: 13.9s
# 305:	learn: 4.5798395	total: 6.13s	remaining: 13.9s
# 306:	learn: 4.5758256	total: 6.15s	remaining: 13.9s
# 307:	learn: 4.5719859	total: 6.17s	remaining: 13.9s
# 308:	learn: 4.5678473	total: 6.18s	remaining: 13.8s
# 309:	learn: 4.5621939	total: 6.21s	remaining: 13.8s
# 310:	learn: 4.5592855	total: 6.23s	remaining: 13.8s
# 311:	learn: 4.5526947	total: 6.25s	remaining: 13.8s
# 312:	learn: 4.5470176	total: 6.27s	remaining: 13.8s
# 313:	learn: 4.5392881	total: 6.29s	remaining: 13.7s
# 314:	learn: 4.5339028	total: 6.31s	remaining: 13.7s
# 315:	learn: 4.5319410	total: 6.33s	remaining: 13.7s
# 316:	learn: 4.5258243	total: 6.35s	remaining: 13.7s
# 317:	learn: 4.5231266	total: 6.37s	remaining: 13.7s
# 318:	learn: 4.5210819	total: 6.39s	remaining: 13.6s
# 319:	learn: 4.5174651	total: 6.41s	remaining: 13.6s
# 320:	learn: 4.5152885	total: 6.43s	remaining: 13.6s
# 321:	learn: 4.5133321	total: 6.45s	remaining: 13.6s
# 322:	learn: 4.5110980	total: 6.48s	remaining: 13.6s
# 323:	learn: 4.5093404	total: 6.5s	remaining: 13.6s
# 324:	learn: 4.5039228	total: 6.52s	remaining: 13.5s
# 325:	learn: 4.4983878	total: 6.54s	remaining: 13.5s
# 326:	learn: 4.4944083	total: 6.56s	remaining: 13.5s
# 327:	learn: 4.4883209	total: 6.59s	remaining: 13.5s
# 328:	learn: 4.4864586	total: 6.61s	remaining: 13.5s
# 329:	learn: 4.4846293	total: 6.63s	remaining: 13.5s
# 330:	learn: 4.4828272	total: 6.65s	remaining: 13.4s
# 331:	learn: 4.4774296	total: 6.67s	remaining: 13.4s
# 332:	learn: 4.4757664	total: 6.69s	remaining: 13.4s
# 333:	learn: 4.4739403	total: 6.71s	remaining: 13.4s
# 334:	learn: 4.4691940	total: 6.74s	remaining: 13.4s
# 335:	learn: 4.4674352	total: 6.75s	remaining: 13.3s
# 336:	learn: 4.4617976	total: 6.78s	remaining: 13.3s
# 337:	learn: 4.4580522	total: 6.8s	remaining: 13.3s
# 338:	learn: 4.4562989	total: 6.82s	remaining: 13.3s
# 339:	learn: 4.4497713	total: 6.85s	remaining: 13.3s
# 340:	learn: 4.4480670	total: 6.87s	remaining: 13.3s
# 341:	learn: 4.4440380	total: 6.89s	remaining: 13.3s
# 342:	learn: 4.4417786	total: 6.91s	remaining: 13.2s
# 343:	learn: 4.4399308	total: 6.93s	remaining: 13.2s
# 344:	learn: 4.4364113	total: 6.96s	remaining: 13.2s
# 345:	learn: 4.4345659	total: 6.98s	remaining: 13.2s
# 346:	learn: 4.4291715	total: 7s	remaining: 13.2s
# 347:	learn: 4.4249032	total: 7.02s	remaining: 13.1s
# 348:	learn: 4.4182307	total: 7.04s	remaining: 13.1s
# 349:	learn: 4.4155747	total: 7.06s	remaining: 13.1s
# 350:	learn: 4.4139959	total: 7.08s	remaining: 13.1s
# 351:	learn: 4.4088757	total: 7.1s	remaining: 13.1s
# 352:	learn: 4.4055037	total: 7.12s	remaining: 13s
# 353:	learn: 4.4037115	total: 7.14s	remaining: 13s
# 354:	learn: 4.4019109	total: 7.16s	remaining: 13s
# 355:	learn: 4.3988272	total: 7.18s	remaining: 13s
# 356:	learn: 4.3971075	total: 7.2s	remaining: 13s
# 357:	learn: 4.3903414	total: 7.22s	remaining: 12.9s
# 358:	learn: 4.3848421	total: 7.24s	remaining: 12.9s
# 359:	learn: 4.3819835	total: 7.26s	remaining: 12.9s
# 360:	learn: 4.3779645	total: 7.28s	remaining: 12.9s
# 361:	learn: 4.3742090	total: 7.3s	remaining: 12.9s
# 362:	learn: 4.3723890	total: 7.33s	remaining: 12.9s
# 363:	learn: 4.3708016	total: 7.35s	remaining: 12.8s
# 364:	learn: 4.3691523	total: 7.37s	remaining: 12.8s
# 365:	learn: 4.3655814	total: 7.39s	remaining: 12.8s
# 366:	learn: 4.3633369	total: 7.41s	remaining: 12.8s
# 367:	learn: 4.3597111	total: 7.43s	remaining: 12.8s
# 368:	learn: 4.3578381	total: 7.45s	remaining: 12.7s
# 369:	learn: 4.3552757	total: 7.47s	remaining: 12.7s
# 370:	learn: 4.3522253	total: 7.49s	remaining: 12.7s
# 371:	learn: 4.3463354	total: 7.51s	remaining: 12.7s
# 372:	learn: 4.3415406	total: 7.53s	remaining: 12.7s
# 373:	learn: 4.3397483	total: 7.55s	remaining: 12.6s
# 374:	learn: 4.3363428	total: 7.57s	remaining: 12.6s
# 375:	learn: 4.3317273	total: 7.59s	remaining: 12.6s
# 376:	learn: 4.3300195	total: 7.61s	remaining: 12.6s
# 377:	learn: 4.3282179	total: 7.63s	remaining: 12.6s
# 378:	learn: 4.3266813	total: 7.65s	remaining: 12.5s
# 379:	learn: 4.3213873	total: 7.67s	remaining: 12.5s
# 380:	learn: 4.3169489	total: 7.69s	remaining: 12.5s
# 381:	learn: 4.3155701	total: 7.71s	remaining: 12.5s
# 382:	learn: 4.3065494	total: 7.73s	remaining: 12.4s
# 383:	learn: 4.3048744	total: 7.75s	remaining: 12.4s
# 384:	learn: 4.3032996	total: 7.77s	remaining: 12.4s
# 385:	learn: 4.3005286	total: 7.79s	remaining: 12.4s
# 386:	learn: 4.2967449	total: 7.81s	remaining: 12.4s
# 387:	learn: 4.2935072	total: 7.83s	remaining: 12.3s
# 388:	learn: 4.2912603	total: 7.85s	remaining: 12.3s
# 389:	learn: 4.2885233	total: 7.87s	remaining: 12.3s
# 390:	learn: 4.2826566	total: 7.88s	remaining: 12.3s
# 391:	learn: 4.2803533	total: 7.91s	remaining: 12.3s
# 392:	learn: 4.2787412	total: 7.92s	remaining: 12.2s
# 393:	learn: 4.2752817	total: 7.95s	remaining: 12.2s
# 394:	learn: 4.2722573	total: 7.96s	remaining: 12.2s
# 395:	learn: 4.2707531	total: 7.98s	remaining: 12.2s
# 396:	learn: 4.2695063	total: 8s	remaining: 12.2s
# 397:	learn: 4.2680138	total: 8.03s	remaining: 12.1s
# 398:	learn: 4.2664941	total: 8.04s	remaining: 12.1s
# 399:	learn: 4.2650210	total: 8.06s	remaining: 12.1s
# 400:	learn: 4.2608922	total: 8.08s	remaining: 12.1s
# 401:	learn: 4.2558141	total: 8.1s	remaining: 12s
# 402:	learn: 4.2537959	total: 8.12s	remaining: 12s
# 403:	learn: 4.2482550	total: 8.14s	remaining: 12s
# 404:	learn: 4.2466480	total: 8.16s	remaining: 12s
# 405:	learn: 4.2453044	total: 8.18s	remaining: 12s
# 406:	learn: 4.2395739	total: 8.2s	remaining: 11.9s
# 407:	learn: 4.2369100	total: 8.22s	remaining: 11.9s
# 408:	learn: 4.2327076	total: 8.23s	remaining: 11.9s
# 409:	learn: 4.2311260	total: 8.26s	remaining: 11.9s
# 410:	learn: 4.2266030	total: 8.27s	remaining: 11.9s
# 411:	learn: 4.2234390	total: 8.29s	remaining: 11.8s
# 412:	learn: 4.2217302	total: 8.31s	remaining: 11.8s
# 413:	learn: 4.2189047	total: 8.33s	remaining: 11.8s
# 414:	learn: 4.2171607	total: 8.36s	remaining: 11.8s
# 415:	learn: 4.2150339	total: 8.38s	remaining: 11.8s
# 416:	learn: 4.2109323	total: 8.39s	remaining: 11.7s
# 417:	learn: 4.2092713	total: 8.41s	remaining: 11.7s
# 418:	learn: 4.2042718	total: 8.43s	remaining: 11.7s
# 419:	learn: 4.1984400	total: 8.45s	remaining: 11.7s
# 420:	learn: 4.1940195	total: 8.47s	remaining: 11.7s
# 421:	learn: 4.1925325	total: 8.49s	remaining: 11.6s
# 422:	learn: 4.1901051	total: 8.51s	remaining: 11.6s
# 423:	learn: 4.1875285	total: 8.54s	remaining: 11.6s
# 424:	learn: 4.1816243	total: 8.55s	remaining: 11.6s
# 425:	learn: 4.1782940	total: 8.58s	remaining: 11.6s
# 426:	learn: 4.1746571	total: 8.6s	remaining: 11.5s
# 427:	learn: 4.1709063	total: 8.62s	remaining: 11.5s
# 428:	learn: 4.1660927	total: 8.63s	remaining: 11.5s
# 429:	learn: 4.1630500	total: 8.65s	remaining: 11.5s
# 430:	learn: 4.1601405	total: 8.67s	remaining: 11.5s
# 431:	learn: 4.1587262	total: 8.69s	remaining: 11.4s
# 432:	learn: 4.1547433	total: 8.71s	remaining: 11.4s
# 433:	learn: 4.1506278	total: 8.73s	remaining: 11.4s
# 434:	learn: 4.1483585	total: 8.75s	remaining: 11.4s
# 435:	learn: 4.1470367	total: 8.77s	remaining: 11.3s
# 436:	learn: 4.1455088	total: 8.79s	remaining: 11.3s
# 437:	learn: 4.1431559	total: 8.82s	remaining: 11.3s
# 438:	learn: 4.1412173	total: 8.84s	remaining: 11.3s
# 439:	learn: 4.1395094	total: 8.86s	remaining: 11.3s
# 440:	learn: 4.1380803	total: 8.88s	remaining: 11.3s
# 441:	learn: 4.1368706	total: 8.9s	remaining: 11.2s
# 442:	learn: 4.1353052	total: 8.92s	remaining: 11.2s
# 443:	learn: 4.1338934	total: 8.95s	remaining: 11.2s
# 444:	learn: 4.1312022	total: 8.97s	remaining: 11.2s
# 445:	learn: 4.1255719	total: 8.99s	remaining: 11.2s
# 446:	learn: 4.1243079	total: 9.01s	remaining: 11.2s
# 447:	learn: 4.1230415	total: 9.03s	remaining: 11.1s
# 448:	learn: 4.1215197	total: 9.05s	remaining: 11.1s
# 449:	learn: 4.1189627	total: 9.07s	remaining: 11.1s
# 450:	learn: 4.1173612	total: 9.09s	remaining: 11.1s
# 451:	learn: 4.1160057	total: 9.11s	remaining: 11s
# 452:	learn: 4.1148098	total: 9.13s	remaining: 11s
# 453:	learn: 4.1102218	total: 9.15s	remaining: 11s
# 454:	learn: 4.1087949	total: 9.17s	remaining: 11s
# 455:	learn: 4.1059944	total: 9.19s	remaining: 11s
# 456:	learn: 4.1047853	total: 9.21s	remaining: 10.9s
# 457:	learn: 4.1027997	total: 9.23s	remaining: 10.9s
# 458:	learn: 4.0992473	total: 9.25s	remaining: 10.9s
# 459:	learn: 4.0965678	total: 9.27s	remaining: 10.9s
# 460:	learn: 4.0946227	total: 9.29s	remaining: 10.9s
# 461:	learn: 4.0915620	total: 9.31s	remaining: 10.8s
# 462:	learn: 4.0887092	total: 9.34s	remaining: 10.8s
# 463:	learn: 4.0871599	total: 9.36s	remaining: 10.8s
# 464:	learn: 4.0858832	total: 9.38s	remaining: 10.8s
# 465:	learn: 4.0809245	total: 9.4s	remaining: 10.8s
# 466:	learn: 4.0796527	total: 9.42s	remaining: 10.7s
# 467:	learn: 4.0747390	total: 9.44s	remaining: 10.7s
# 468:	learn: 4.0713290	total: 9.46s	remaining: 10.7s
# 469:	learn: 4.0699654	total: 9.47s	remaining: 10.7s
# 470:	learn: 4.0673415	total: 9.49s	remaining: 10.7s
# 471:	learn: 4.0642914	total: 9.51s	remaining: 10.6s
# 472:	learn: 4.0617393	total: 9.54s	remaining: 10.6s
# 473:	learn: 4.0588905	total: 9.55s	remaining: 10.6s
# 474:	learn: 4.0554058	total: 9.57s	remaining: 10.6s
# 475:	learn: 4.0541440	total: 9.59s	remaining: 10.6s
# 476:	learn: 4.0528700	total: 9.61s	remaining: 10.5s
# 477:	learn: 4.0514994	total: 9.63s	remaining: 10.5s
# 478:	learn: 4.0474299	total: 9.65s	remaining: 10.5s
# 479:	learn: 4.0404706	total: 9.67s	remaining: 10.5s
# 480:	learn: 4.0381005	total: 9.69s	remaining: 10.5s
# 481:	learn: 4.0367014	total: 9.71s	remaining: 10.4s
# 482:	learn: 4.0353465	total: 9.73s	remaining: 10.4s
# 483:	learn: 4.0320078	total: 9.75s	remaining: 10.4s
# 484:	learn: 4.0287435	total: 9.77s	remaining: 10.4s
# 485:	learn: 4.0250568	total: 9.79s	remaining: 10.4s
# 486:	learn: 4.0206018	total: 9.81s	remaining: 10.3s
# 487:	learn: 4.0171610	total: 9.83s	remaining: 10.3s
# 488:	learn: 4.0158193	total: 9.85s	remaining: 10.3s
# 489:	learn: 4.0107305	total: 9.87s	remaining: 10.3s
# 490:	learn: 4.0073343	total: 9.89s	remaining: 10.3s
# 491:	learn: 4.0045880	total: 9.91s	remaining: 10.2s
# 492:	learn: 4.0031523	total: 9.93s	remaining: 10.2s
# 493:	learn: 4.0018791	total: 9.95s	remaining: 10.2s
# 494:	learn: 3.9986211	total: 9.97s	remaining: 10.2s
# 495:	learn: 3.9973073	total: 9.99s	remaining: 10.2s
# 496:	learn: 3.9952647	total: 10s	remaining: 10.1s
# 497:	learn: 3.9907544	total: 10s	remaining: 10.1s
# 498:	learn: 3.9884649	total: 10.1s	remaining: 10.1s
# 499:	learn: 3.9845944	total: 10.1s	remaining: 10.1s
# 500:	learn: 3.9827953	total: 10.1s	remaining: 10.1s
# 501:	learn: 3.9760769	total: 10.1s	remaining: 10s
# 502:	learn: 3.9718832	total: 10.1s	remaining: 10s
# 503:	learn: 3.9706264	total: 10.2s	remaining: 10s
# 504:	learn: 3.9694405	total: 10.2s	remaining: 9.98s
# 505:	learn: 3.9673422	total: 10.2s	remaining: 9.97s
# 506:	learn: 3.9631675	total: 10.2s	remaining: 9.95s
# 507:	learn: 3.9618013	total: 10.3s	remaining: 9.93s
# 508:	learn: 3.9599242	total: 10.3s	remaining: 9.91s
# 509:	learn: 3.9585383	total: 10.3s	remaining: 9.89s
# 510:	learn: 3.9573263	total: 10.3s	remaining: 9.87s
# 511:	learn: 3.9537031	total: 10.3s	remaining: 9.85s
# 512:	learn: 3.9487599	total: 10.4s	remaining: 9.83s
# 513:	learn: 3.9461586	total: 10.4s	remaining: 9.81s
# 514:	learn: 3.9445928	total: 10.4s	remaining: 9.79s
# 515:	learn: 3.9410078	total: 10.4s	remaining: 9.77s
# 516:	learn: 3.9398431	total: 10.4s	remaining: 9.75s
# 517:	learn: 3.9368838	total: 10.5s	remaining: 9.73s
# 518:	learn: 3.9358250	total: 10.5s	remaining: 9.71s
# 519:	learn: 3.9336238	total: 10.5s	remaining: 9.69s
# 520:	learn: 3.9274893	total: 10.5s	remaining: 9.67s
# 521:	learn: 3.9253637	total: 10.5s	remaining: 9.65s
# 522:	learn: 3.9241247	total: 10.6s	remaining: 9.63s
# 523:	learn: 3.9214422	total: 10.6s	remaining: 9.61s
# 524:	learn: 3.9164168	total: 10.6s	remaining: 9.59s
# 525:	learn: 3.9150860	total: 10.6s	remaining: 9.57s
# 526:	learn: 3.9137443	total: 10.6s	remaining: 9.55s
# 527:	learn: 3.9104552	total: 10.7s	remaining: 9.53s
# 528:	learn: 3.9092857	total: 10.7s	remaining: 9.52s
# 529:	learn: 3.9056416	total: 10.7s	remaining: 9.49s
# 530:	learn: 3.9028950	total: 10.7s	remaining: 9.47s
# 531:	learn: 3.8998165	total: 10.7s	remaining: 9.46s
# 532:	learn: 3.8961295	total: 10.8s	remaining: 9.44s
# 533:	learn: 3.8943676	total: 10.8s	remaining: 9.42s
# 534:	learn: 3.8914715	total: 10.8s	remaining: 9.4s
# 535:	learn: 3.8902298	total: 10.8s	remaining: 9.38s
# 536:	learn: 3.8856260	total: 10.9s	remaining: 9.37s
# 537:	learn: 3.8815218	total: 10.9s	remaining: 9.35s
# 538:	learn: 3.8798431	total: 10.9s	remaining: 9.33s
# 539:	learn: 3.8771983	total: 10.9s	remaining: 9.3s
# 540:	learn: 3.8733333	total: 10.9s	remaining: 9.29s
# 541:	learn: 3.8713912	total: 11s	remaining: 9.27s
# 542:	learn: 3.8701019	total: 11s	remaining: 9.24s
# 543:	learn: 3.8649383	total: 11s	remaining: 9.22s
# 544:	learn: 3.8614563	total: 11s	remaining: 9.2s
# 545:	learn: 3.8588529	total: 11s	remaining: 9.18s
# 546:	learn: 3.8544907	total: 11.1s	remaining: 9.16s
# 547:	learn: 3.8499863	total: 11.1s	remaining: 9.14s
# 548:	learn: 3.8473627	total: 11.1s	remaining: 9.12s
# 549:	learn: 3.8438277	total: 11.1s	remaining: 9.1s
# 550:	learn: 3.8426447	total: 11.1s	remaining: 9.08s
# 551:	learn: 3.8413729	total: 11.2s	remaining: 9.05s
# 552:	learn: 3.8380094	total: 11.2s	remaining: 9.04s
# 553:	learn: 3.8368120	total: 11.2s	remaining: 9.02s
# 554:	learn: 3.8355569	total: 11.2s	remaining: 9s
# 555:	learn: 3.8343119	total: 11.2s	remaining: 8.98s
# 556:	learn: 3.8331719	total: 11.3s	remaining: 8.96s
# 557:	learn: 3.8275152	total: 11.3s	remaining: 8.94s
# 558:	learn: 3.8230404	total: 11.3s	remaining: 8.91s
# 559:	learn: 3.8220124	total: 11.3s	remaining: 8.89s
# 560:	learn: 3.8165890	total: 11.3s	remaining: 8.87s
# 561:	learn: 3.8137268	total: 11.4s	remaining: 8.85s
# 562:	learn: 3.8126312	total: 11.4s	remaining: 8.83s
# 563:	learn: 3.8089666	total: 11.4s	remaining: 8.81s
# 564:	learn: 3.8064525	total: 11.4s	remaining: 8.79s
# 565:	learn: 3.8052988	total: 11.4s	remaining: 8.77s
# 566:	learn: 3.8025893	total: 11.5s	remaining: 8.75s
# 567:	learn: 3.7990991	total: 11.5s	remaining: 8.73s
# 568:	learn: 3.7979478	total: 11.5s	remaining: 8.71s
# 569:	learn: 3.7966705	total: 11.5s	remaining: 8.69s
# 570:	learn: 3.7929625	total: 11.5s	remaining: 8.67s
# 571:	learn: 3.7908943	total: 11.6s	remaining: 8.65s
# 572:	learn: 3.7885330	total: 11.6s	remaining: 8.63s
# 573:	learn: 3.7872300	total: 11.6s	remaining: 8.61s
# 574:	learn: 3.7847561	total: 11.6s	remaining: 8.59s
# 575:	learn: 3.7825057	total: 11.6s	remaining: 8.57s
# 576:	learn: 3.7785955	total: 11.7s	remaining: 8.55s
# 577:	learn: 3.7762322	total: 11.7s	remaining: 8.54s
# 578:	learn: 3.7739090	total: 11.7s	remaining: 8.52s
# 579:	learn: 3.7717207	total: 11.7s	remaining: 8.5s
# 580:	learn: 3.7690888	total: 11.8s	remaining: 8.48s
# 581:	learn: 3.7676756	total: 11.8s	remaining: 8.46s
# 582:	learn: 3.7664648	total: 11.8s	remaining: 8.44s
# 583:	learn: 3.7653638	total: 11.8s	remaining: 8.42s
# 584:	learn: 3.7639426	total: 11.8s	remaining: 8.4s
# 585:	learn: 3.7595288	total: 11.9s	remaining: 8.38s
# 586:	learn: 3.7583445	total: 11.9s	remaining: 8.36s
# 587:	learn: 3.7558454	total: 11.9s	remaining: 8.34s
# 588:	learn: 3.7539154	total: 11.9s	remaining: 8.31s
# 589:	learn: 3.7503533	total: 11.9s	remaining: 8.29s
# 590:	learn: 3.7492639	total: 12s	remaining: 8.27s
# 591:	learn: 3.7445069	total: 12s	remaining: 8.25s
# 592:	learn: 3.7433689	total: 12s	remaining: 8.23s
# 593:	learn: 3.7406859	total: 12s	remaining: 8.21s
# 594:	learn: 3.7377794	total: 12s	remaining: 8.19s
# 595:	learn: 3.7367858	total: 12.1s	remaining: 8.17s
# 596:	learn: 3.7353042	total: 12.1s	remaining: 8.15s
# 597:	learn: 3.7317600	total: 12.1s	remaining: 8.13s
# 598:	learn: 3.7306912	total: 12.1s	remaining: 8.11s
# 599:	learn: 3.7294029	total: 12.1s	remaining: 8.09s
# 600:	learn: 3.7269178	total: 12.1s	remaining: 8.06s
# 601:	learn: 3.7257251	total: 12.2s	remaining: 8.04s
# 602:	learn: 3.7230053	total: 12.2s	remaining: 8.02s
# 603:	learn: 3.7218891	total: 12.2s	remaining: 8s
# 604:	learn: 3.7187430	total: 12.2s	remaining: 7.98s
# 605:	learn: 3.7157761	total: 12.2s	remaining: 7.96s
# 606:	learn: 3.7137514	total: 12.3s	remaining: 7.94s
# 607:	learn: 3.7113717	total: 12.3s	remaining: 7.92s
# 608:	learn: 3.7089612	total: 12.3s	remaining: 7.9s
# 609:	learn: 3.7078966	total: 12.3s	remaining: 7.88s
# 610:	learn: 3.7054821	total: 12.3s	remaining: 7.86s
# 611:	learn: 3.7044994	total: 12.4s	remaining: 7.83s
# 612:	learn: 3.7034129	total: 12.4s	remaining: 7.81s
# 613:	learn: 3.7023746	total: 12.4s	remaining: 7.79s
# 614:	learn: 3.6989788	total: 12.4s	remaining: 7.78s
# 615:	learn: 3.6975228	total: 12.4s	remaining: 7.75s
# 616:	learn: 3.6965056	total: 12.5s	remaining: 7.74s
# 617:	learn: 3.6954056	total: 12.5s	remaining: 7.71s
# 618:	learn: 3.6942438	total: 12.5s	remaining: 7.69s
# 619:	learn: 3.6932680	total: 12.5s	remaining: 7.67s
# 620:	learn: 3.6908746	total: 12.5s	remaining: 7.65s
# 621:	learn: 3.6883495	total: 12.6s	remaining: 7.63s
# 622:	learn: 3.6872399	total: 12.6s	remaining: 7.62s
# 623:	learn: 3.6841441	total: 12.6s	remaining: 7.6s
# 624:	learn: 3.6832195	total: 12.6s	remaining: 7.58s
# 625:	learn: 3.6818607	total: 12.7s	remaining: 7.56s
# 626:	learn: 3.6809043	total: 12.7s	remaining: 7.54s
# 627:	learn: 3.6797753	total: 12.7s	remaining: 7.53s
# 628:	learn: 3.6773964	total: 12.7s	remaining: 7.51s
# 629:	learn: 3.6764063	total: 12.8s	remaining: 7.49s
# 630:	learn: 3.6740635	total: 12.8s	remaining: 7.47s
# 631:	learn: 3.6707566	total: 12.8s	remaining: 7.45s
# 632:	learn: 3.6689697	total: 12.8s	remaining: 7.43s
# 633:	learn: 3.6658251	total: 12.8s	remaining: 7.41s
# 634:	learn: 3.6616851	total: 12.9s	remaining: 7.39s
# 635:	learn: 3.6605957	total: 12.9s	remaining: 7.37s
# 636:	learn: 3.6556196	total: 12.9s	remaining: 7.35s
# 637:	learn: 3.6529852	total: 12.9s	remaining: 7.33s
# 638:	learn: 3.6520989	total: 12.9s	remaining: 7.3s
# 639:	learn: 3.6493800	total: 13s	remaining: 7.29s
# 640:	learn: 3.6460584	total: 13s	remaining: 7.26s
# 641:	learn: 3.6427319	total: 13s	remaining: 7.24s
# 642:	learn: 3.6418755	total: 13s	remaining: 7.23s
# 643:	learn: 3.6409507	total: 13s	remaining: 7.21s
# 644:	learn: 3.6387602	total: 13.1s	remaining: 7.19s
# 645:	learn: 3.6363470	total: 13.1s	remaining: 7.17s
# 646:	learn: 3.6342923	total: 13.1s	remaining: 7.15s
# 647:	learn: 3.6322001	total: 13.1s	remaining: 7.13s
# 648:	learn: 3.6300248	total: 13.1s	remaining: 7.11s
# 649:	learn: 3.6273133	total: 13.2s	remaining: 7.09s
# 650:	learn: 3.6262659	total: 13.2s	remaining: 7.07s
# 651:	learn: 3.6249694	total: 13.2s	remaining: 7.05s
# 652:	learn: 3.6221151	total: 13.2s	remaining: 7.03s
# 653:	learn: 3.6210361	total: 13.2s	remaining: 7.01s
# 654:	learn: 3.6178263	total: 13.3s	remaining: 6.99s
# 655:	learn: 3.6168861	total: 13.3s	remaining: 6.97s
# 656:	learn: 3.6146866	total: 13.3s	remaining: 6.95s
# 657:	learn: 3.6129900	total: 13.3s	remaining: 6.93s
# 658:	learn: 3.6120439	total: 13.3s	remaining: 6.91s
# 659:	learn: 3.6087644	total: 13.4s	remaining: 6.89s
# 660:	learn: 3.6066369	total: 13.4s	remaining: 6.87s
# 661:	learn: 3.6056932	total: 13.4s	remaining: 6.85s
# 662:	learn: 3.6030920	total: 13.4s	remaining: 6.83s
# 663:	learn: 3.6006722	total: 13.5s	remaining: 6.81s
# 664:	learn: 3.5996398	total: 13.5s	remaining: 6.79s
# 665:	learn: 3.5976953	total: 13.5s	remaining: 6.77s
# 666:	learn: 3.5947307	total: 13.5s	remaining: 6.75s
# 667:	learn: 3.5919593	total: 13.5s	remaining: 6.73s
# 668:	learn: 3.5909356	total: 13.6s	remaining: 6.71s
# 669:	learn: 3.5889982	total: 13.6s	remaining: 6.68s
# 670:	learn: 3.5879548	total: 13.6s	remaining: 6.66s
# 671:	learn: 3.5870475	total: 13.6s	remaining: 6.64s
# 672:	learn: 3.5851809	total: 13.6s	remaining: 6.62s
# 673:	learn: 3.5817373	total: 13.7s	remaining: 6.6s
# 674:	learn: 3.5793487	total: 13.7s	remaining: 6.58s
# 675:	learn: 3.5781756	total: 13.7s	remaining: 6.56s
# 676:	learn: 3.5750529	total: 13.7s	remaining: 6.54s
# 677:	learn: 3.5728699	total: 13.7s	remaining: 6.52s
# 678:	learn: 3.5719188	total: 13.7s	remaining: 6.5s
# 679:	learn: 3.5698975	total: 13.8s	remaining: 6.48s
# 680:	learn: 3.5666502	total: 13.8s	remaining: 6.46s
# 681:	learn: 3.5657099	total: 13.8s	remaining: 6.44s
# 682:	learn: 3.5647146	total: 13.8s	remaining: 6.42s
# 683:	learn: 3.5637486	total: 13.8s	remaining: 6.4s
# 684:	learn: 3.5628585	total: 13.9s	remaining: 6.38s
# 685:	learn: 3.5610768	total: 13.9s	remaining: 6.36s
# 686:	learn: 3.5579034	total: 13.9s	remaining: 6.34s
# 687:	learn: 3.5536012	total: 13.9s	remaining: 6.32s
# 688:	learn: 3.5495322	total: 13.9s	remaining: 6.3s
# 689:	learn: 3.5483560	total: 14s	remaining: 6.27s
# 690:	learn: 3.5475055	total: 14s	remaining: 6.25s
# 691:	learn: 3.5456094	total: 14s	remaining: 6.23s
# 692:	learn: 3.5427842	total: 14s	remaining: 6.21s
# 693:	learn: 3.5405436	total: 14s	remaining: 6.19s
# 694:	learn: 3.5379608	total: 14.1s	remaining: 6.17s
# 695:	learn: 3.5368472	total: 14.1s	remaining: 6.15s
# 696:	learn: 3.5358260	total: 14.1s	remaining: 6.13s
# 697:	learn: 3.5348814	total: 14.1s	remaining: 6.11s
# 698:	learn: 3.5339557	total: 14.1s	remaining: 6.09s
# 699:	learn: 3.5329576	total: 14.2s	remaining: 6.07s
# 700:	learn: 3.5314235	total: 14.2s	remaining: 6.05s
# 701:	learn: 3.5305926	total: 14.2s	remaining: 6.03s
# 702:	learn: 3.5275403	total: 14.2s	remaining: 6s
# 703:	learn: 3.5240727	total: 14.2s	remaining: 5.98s
# 704:	learn: 3.5204017	total: 14.3s	remaining: 5.96s
# 705:	learn: 3.5191183	total: 14.3s	remaining: 5.94s
# 706:	learn: 3.5182809	total: 14.3s	remaining: 5.92s
# 707:	learn: 3.5151276	total: 14.3s	remaining: 5.9s
# 708:	learn: 3.5134138	total: 14.3s	remaining: 5.88s
# 709:	learn: 3.5108702	total: 14.3s	remaining: 5.86s
# 710:	learn: 3.5095387	total: 14.4s	remaining: 5.84s
# 711:	learn: 3.5073386	total: 14.4s	remaining: 5.82s
# 712:	learn: 3.5049116	total: 14.4s	remaining: 5.8s
# 713:	learn: 3.5019210	total: 14.4s	remaining: 5.78s
# 714:	learn: 3.5007470	total: 14.4s	remaining: 5.76s
# 715:	learn: 3.4999030	total: 14.5s	remaining: 5.74s
# 716:	learn: 3.4988837	total: 14.5s	remaining: 5.72s
# 717:	learn: 3.4975748	total: 14.5s	remaining: 5.7s
# 718:	learn: 3.4951973	total: 14.5s	remaining: 5.68s
# 719:	learn: 3.4933941	total: 14.5s	remaining: 5.66s
# 720:	learn: 3.4924853	total: 14.6s	remaining: 5.63s
# 721:	learn: 3.4896710	total: 14.6s	remaining: 5.61s
# 722:	learn: 3.4884450	total: 14.6s	remaining: 5.59s
# 723:	learn: 3.4859151	total: 14.6s	remaining: 5.58s
# 724:	learn: 3.4830626	total: 14.6s	remaining: 5.55s
# 725:	learn: 3.4808320	total: 14.7s	remaining: 5.53s
# 726:	learn: 3.4782364	total: 14.7s	remaining: 5.51s
# 727:	learn: 3.4772298	total: 14.7s	remaining: 5.49s
# 728:	learn: 3.4759178	total: 14.7s	remaining: 5.47s
# 729:	learn: 3.4750368	total: 14.7s	remaining: 5.45s
# 730:	learn: 3.4740451	total: 14.8s	remaining: 5.43s
# 731:	learn: 3.4707141	total: 14.8s	remaining: 5.41s
# 732:	learn: 3.4698211	total: 14.8s	remaining: 5.39s
# 733:	learn: 3.4672923	total: 14.8s	remaining: 5.37s
# 734:	learn: 3.4659334	total: 14.8s	remaining: 5.35s
# 735:	learn: 3.4635001	total: 14.9s	remaining: 5.33s
# 736:	learn: 3.4617728	total: 14.9s	remaining: 5.31s
# 737:	learn: 3.4606255	total: 14.9s	remaining: 5.29s
# 738:	learn: 3.4586302	total: 14.9s	remaining: 5.27s
# 739:	learn: 3.4555244	total: 14.9s	remaining: 5.25s
# 740:	learn: 3.4540607	total: 15s	remaining: 5.23s
# 741:	learn: 3.4527194	total: 15s	remaining: 5.21s
# 742:	learn: 3.4511380	total: 15s	remaining: 5.19s
# 743:	learn: 3.4502194	total: 15s	remaining: 5.17s
# 744:	learn: 3.4491493	total: 15s	remaining: 5.15s
# 745:	learn: 3.4482709	total: 15.1s	remaining: 5.13s
# 746:	learn: 3.4473527	total: 15.1s	remaining: 5.11s
# 747:	learn: 3.4445011	total: 15.1s	remaining: 5.09s
# 748:	learn: 3.4436339	total: 15.1s	remaining: 5.07s
# 749:	learn: 3.4428229	total: 15.1s	remaining: 5.04s
# 750:	learn: 3.4415120	total: 15.2s	remaining: 5.03s
# 751:	learn: 3.4402894	total: 15.2s	remaining: 5s
# 752:	learn: 3.4390077	total: 15.2s	remaining: 4.98s
# 753:	learn: 3.4383592	total: 15.2s	remaining: 4.96s
# 754:	learn: 3.4360795	total: 15.2s	remaining: 4.94s
# 755:	learn: 3.4351130	total: 15.3s	remaining: 4.92s
# 756:	learn: 3.4331660	total: 15.3s	remaining: 4.9s
# 757:	learn: 3.4323516	total: 15.3s	remaining: 4.88s
# 758:	learn: 3.4304071	total: 15.3s	remaining: 4.86s
# 759:	learn: 3.4277847	total: 15.3s	remaining: 4.84s
# 760:	learn: 3.4268884	total: 15.4s	remaining: 4.82s
# 761:	learn: 3.4260116	total: 15.4s	remaining: 4.8s
# 762:	learn: 3.4231486	total: 15.4s	remaining: 4.78s
# 763:	learn: 3.4210222	total: 15.4s	remaining: 4.76s
# 764:	learn: 3.4201020	total: 15.4s	remaining: 4.74s
# 765:	learn: 3.4191604	total: 15.5s	remaining: 4.72s
# 766:	learn: 3.4168052	total: 15.5s	remaining: 4.7s
# 767:	learn: 3.4159809	total: 15.5s	remaining: 4.68s
# 768:	learn: 3.4132261	total: 15.5s	remaining: 4.66s
# 769:	learn: 3.4125188	total: 15.5s	remaining: 4.64s
# 770:	learn: 3.4117152	total: 15.6s	remaining: 4.62s
# 771:	learn: 3.4109947	total: 15.6s	remaining: 4.6s
# 772:	learn: 3.4092505	total: 15.6s	remaining: 4.58s
# 773:	learn: 3.4063466	total: 15.6s	remaining: 4.56s
# 774:	learn: 3.4040905	total: 15.6s	remaining: 4.54s
# 775:	learn: 3.4032173	total: 15.6s	remaining: 4.52s
# 776:	learn: 3.4022805	total: 15.7s	remaining: 4.5s
# 777:	learn: 3.4005498	total: 15.7s	remaining: 4.48s
# 778:	learn: 3.3961589	total: 15.7s	remaining: 4.46s
# 779:	learn: 3.3919889	total: 15.7s	remaining: 4.43s
# 780:	learn: 3.3905967	total: 15.7s	remaining: 4.41s
# 781:	learn: 3.3898357	total: 15.8s	remaining: 4.39s
# 782:	learn: 3.3890046	total: 15.8s	remaining: 4.37s
# 783:	learn: 3.3870805	total: 15.8s	remaining: 4.35s
# 784:	learn: 3.3858679	total: 15.8s	remaining: 4.33s
# 785:	learn: 3.3847122	total: 15.8s	remaining: 4.32s
# 786:	learn: 3.3827826	total: 15.9s	remaining: 4.29s
# 787:	learn: 3.3798990	total: 15.9s	remaining: 4.28s
# 788:	learn: 3.3776188	total: 15.9s	remaining: 4.26s
# 789:	learn: 3.3755464	total: 15.9s	remaining: 4.24s
# 790:	learn: 3.3737778	total: 16s	remaining: 4.22s
# 791:	learn: 3.3728476	total: 16s	remaining: 4.2s
# 792:	learn: 3.3707099	total: 16s	remaining: 4.18s
# 793:	learn: 3.3687651	total: 16s	remaining: 4.16s
# 794:	learn: 3.3679616	total: 16.1s	remaining: 4.14s
# 795:	learn: 3.3659166	total: 16.1s	remaining: 4.12s
# 796:	learn: 3.3649945	total: 16.1s	remaining: 4.1s
# 797:	learn: 3.3610399	total: 16.1s	remaining: 4.08s
# 798:	learn: 3.3602950	total: 16.1s	remaining: 4.06s
# 799:	learn: 3.3584628	total: 16.2s	remaining: 4.04s
# 800:	learn: 3.3558872	total: 16.2s	remaining: 4.02s
# 801:	learn: 3.3541084	total: 16.2s	remaining: 4s
# 802:	learn: 3.3519391	total: 16.2s	remaining: 3.98s
# 803:	learn: 3.3511287	total: 16.2s	remaining: 3.96s
# 804:	learn: 3.3502864	total: 16.3s	remaining: 3.94s
# 805:	learn: 3.3495903	total: 16.3s	remaining: 3.92s
# 806:	learn: 3.3488488	total: 16.3s	remaining: 3.9s
# 807:	learn: 3.3465409	total: 16.3s	remaining: 3.88s
# 808:	learn: 3.3440331	total: 16.3s	remaining: 3.86s
# 809:	learn: 3.3409173	total: 16.4s	remaining: 3.84s
# 810:	learn: 3.3400805	total: 16.4s	remaining: 3.82s
# 811:	learn: 3.3376889	total: 16.4s	remaining: 3.8s
# 812:	learn: 3.3358670	total: 16.4s	remaining: 3.78s
# 813:	learn: 3.3334359	total: 16.4s	remaining: 3.76s
# 814:	learn: 3.3327079	total: 16.5s	remaining: 3.74s
# 815:	learn: 3.3300998	total: 16.5s	remaining: 3.71s
# 816:	learn: 3.3293081	total: 16.5s	remaining: 3.69s
# 817:	learn: 3.3285004	total: 16.5s	remaining: 3.67s
# 818:	learn: 3.3269068	total: 16.5s	remaining: 3.65s
# 819:	learn: 3.3240712	total: 16.6s	remaining: 3.63s
# 820:	learn: 3.3233403	total: 16.6s	remaining: 3.61s
# 821:	learn: 3.3224466	total: 16.6s	remaining: 3.59s
# 822:	learn: 3.3201985	total: 16.6s	remaining: 3.57s
# 823:	learn: 3.3193253	total: 16.6s	remaining: 3.55s
# 824:	learn: 3.3185353	total: 16.7s	remaining: 3.54s
# 825:	learn: 3.3170435	total: 16.7s	remaining: 3.52s
# 826:	learn: 3.3161837	total: 16.7s	remaining: 3.5s
# 827:	learn: 3.3141645	total: 16.7s	remaining: 3.48s
# 828:	learn: 3.3131707	total: 16.8s	remaining: 3.46s
# 829:	learn: 3.3101415	total: 16.8s	remaining: 3.44s
# 830:	learn: 3.3086162	total: 16.8s	remaining: 3.42s
# 831:	learn: 3.3078326	total: 16.8s	remaining: 3.4s
# 832:	learn: 3.3056273	total: 16.8s	remaining: 3.38s
# 833:	learn: 3.3047740	total: 16.9s	remaining: 3.35s
# 834:	learn: 3.3031433	total: 16.9s	remaining: 3.33s
# 835:	learn: 3.3023189	total: 16.9s	remaining: 3.31s
# 836:	learn: 3.2993369	total: 16.9s	remaining: 3.29s
# 837:	learn: 3.2986077	total: 16.9s	remaining: 3.27s
# 838:	learn: 3.2973017	total: 17s	remaining: 3.25s
# 839:	learn: 3.2953815	total: 17s	remaining: 3.23s
# 840:	learn: 3.2935610	total: 17s	remaining: 3.21s
# 841:	learn: 3.2925470	total: 17s	remaining: 3.19s
# 842:	learn: 3.2918538	total: 17s	remaining: 3.17s
# 843:	learn: 3.2888941	total: 17.1s	remaining: 3.15s
# 844:	learn: 3.2884237	total: 17.1s	remaining: 3.13s
# 845:	learn: 3.2876317	total: 17.1s	remaining: 3.11s
# 846:	learn: 3.2864276	total: 17.1s	remaining: 3.09s
# 847:	learn: 3.2830152	total: 17.1s	remaining: 3.07s
# 848:	learn: 3.2812456	total: 17.2s	remaining: 3.05s
# 849:	learn: 3.2804148	total: 17.2s	remaining: 3.03s
# 850:	learn: 3.2786288	total: 17.2s	remaining: 3.01s
# 851:	learn: 3.2778399	total: 17.2s	remaining: 2.99s
# 852:	learn: 3.2768670	total: 17.2s	remaining: 2.97s
# 853:	learn: 3.2754796	total: 17.3s	remaining: 2.95s
# 854:	learn: 3.2748146	total: 17.3s	remaining: 2.93s
# 855:	learn: 3.2727496	total: 17.3s	remaining: 2.91s
# 856:	learn: 3.2719961	total: 17.3s	remaining: 2.89s
# 857:	learn: 3.2695827	total: 17.3s	remaining: 2.87s
# 858:	learn: 3.2678904	total: 17.4s	remaining: 2.85s
# 859:	learn: 3.2658209	total: 17.4s	remaining: 2.83s
# 860:	learn: 3.2651836	total: 17.4s	remaining: 2.81s
# 861:	learn: 3.2638867	total: 17.4s	remaining: 2.79s
# 862:	learn: 3.2625775	total: 17.4s	remaining: 2.77s
# 863:	learn: 3.2617965	total: 17.5s	remaining: 2.75s
# 864:	learn: 3.2601324	total: 17.5s	remaining: 2.73s
# 865:	learn: 3.2576246	total: 17.5s	remaining: 2.71s
# 866:	learn: 3.2560921	total: 17.5s	remaining: 2.69s
# 867:	learn: 3.2553131	total: 17.5s	remaining: 2.67s
# 868:	learn: 3.2537965	total: 17.6s	remaining: 2.65s
# 869:	learn: 3.2530768	total: 17.6s	remaining: 2.63s
# 870:	learn: 3.2522595	total: 17.6s	remaining: 2.61s
# 871:	learn: 3.2509499	total: 17.6s	remaining: 2.58s
# 872:	learn: 3.2499707	total: 17.6s	remaining: 2.56s
# 873:	learn: 3.2492666	total: 17.7s	remaining: 2.54s
# 874:	learn: 3.2461596	total: 17.7s	remaining: 2.52s
# 875:	learn: 3.2442922	total: 17.7s	remaining: 2.5s
# 876:	learn: 3.2430343	total: 17.7s	remaining: 2.48s
# 877:	learn: 3.2422379	total: 17.7s	remaining: 2.46s
# 878:	learn: 3.2392947	total: 17.8s	remaining: 2.44s
# 879:	learn: 3.2378112	total: 17.8s	remaining: 2.42s
# 880:	learn: 3.2370483	total: 17.8s	remaining: 2.4s
# 881:	learn: 3.2359005	total: 17.8s	remaining: 2.38s
# 882:	learn: 3.2350856	total: 17.8s	remaining: 2.36s
# 883:	learn: 3.2338591	total: 17.8s	remaining: 2.34s
# 884:	learn: 3.2322811	total: 17.9s	remaining: 2.32s
# 885:	learn: 3.2300875	total: 17.9s	remaining: 2.3s
# 886:	learn: 3.2293184	total: 17.9s	remaining: 2.28s
# 887:	learn: 3.2285129	total: 17.9s	remaining: 2.26s
# 888:	learn: 3.2272833	total: 17.9s	remaining: 2.24s
# 889:	learn: 3.2258337	total: 18s	remaining: 2.22s
# 890:	learn: 3.2250954	total: 18s	remaining: 2.2s
# 891:	learn: 3.2224943	total: 18s	remaining: 2.18s
# 892:	learn: 3.2204367	total: 18s	remaining: 2.16s
# 893:	learn: 3.2197545	total: 18s	remaining: 2.14s
# 894:	learn: 3.2177906	total: 18.1s	remaining: 2.12s
# 895:	learn: 3.2170551	total: 18.1s	remaining: 2.1s
# 896:	learn: 3.2151710	total: 18.1s	remaining: 2.08s
# 897:	learn: 3.2134255	total: 18.1s	remaining: 2.06s
# 898:	learn: 3.2114851	total: 18.1s	remaining: 2.04s
# 899:	learn: 3.2109069	total: 18.2s	remaining: 2.02s
# 900:	learn: 3.2088612	total: 18.2s	remaining: 2s
# 901:	learn: 3.2081234	total: 18.2s	remaining: 1.98s
# 902:	learn: 3.2074365	total: 18.2s	remaining: 1.96s
# 903:	learn: 3.2065806	total: 18.2s	remaining: 1.94s
# 904:	learn: 3.2058891	total: 18.3s	remaining: 1.92s
# 905:	learn: 3.2034590	total: 18.3s	remaining: 1.9s
# 906:	learn: 3.2014859	total: 18.3s	remaining: 1.88s
# 907:	learn: 3.1995703	total: 18.3s	remaining: 1.85s
# 908:	learn: 3.1976351	total: 18.3s	remaining: 1.83s
# 909:	learn: 3.1969048	total: 18.4s	remaining: 1.81s
# 910:	learn: 3.1947227	total: 18.4s	remaining: 1.79s
# 911:	learn: 3.1933980	total: 18.4s	remaining: 1.77s
# 912:	learn: 3.1928090	total: 18.4s	remaining: 1.75s
# 913:	learn: 3.1921641	total: 18.4s	remaining: 1.73s
# 914:	learn: 3.1900373	total: 18.5s	remaining: 1.71s
# 915:	learn: 3.1889015	total: 18.5s	remaining: 1.69s
# 916:	learn: 3.1877930	total: 18.5s	remaining: 1.67s
# 917:	learn: 3.1864428	total: 18.5s	remaining: 1.65s
# 918:	learn: 3.1853796	total: 18.5s	remaining: 1.63s
# 919:	learn: 3.1839852	total: 18.6s	remaining: 1.61s
# 920:	learn: 3.1831780	total: 18.6s	remaining: 1.59s
# 921:	learn: 3.1824945	total: 18.6s	remaining: 1.57s
# 922:	learn: 3.1806804	total: 18.6s	remaining: 1.55s
# 923:	learn: 3.1799131	total: 18.6s	remaining: 1.53s
# 924:	learn: 3.1779390	total: 18.7s	remaining: 1.51s
# 925:	learn: 3.1766091	total: 18.7s	remaining: 1.49s
# 926:	learn: 3.1751314	total: 18.7s	remaining: 1.47s
# 927:	learn: 3.1741527	total: 18.7s	remaining: 1.45s
# 928:	learn: 3.1721103	total: 18.7s	remaining: 1.43s
# 929:	learn: 3.1715217	total: 18.8s	remaining: 1.41s
# 930:	learn: 3.1692741	total: 18.8s	remaining: 1.39s
# 931:	learn: 3.1675033	total: 18.8s	remaining: 1.37s
# 932:	learn: 3.1667038	total: 18.8s	remaining: 1.35s
# 933:	learn: 3.1644867	total: 18.8s	remaining: 1.33s
# 934:	learn: 3.1624532	total: 18.9s	remaining: 1.31s
# 935:	learn: 3.1603117	total: 18.9s	remaining: 1.29s
# 936:	learn: 3.1594664	total: 18.9s	remaining: 1.27s
# 937:	learn: 3.1588287	total: 18.9s	remaining: 1.25s
# 938:	learn: 3.1573842	total: 18.9s	remaining: 1.23s
# 939:	learn: 3.1566572	total: 19s	remaining: 1.21s
# 940:	learn: 3.1556939	total: 19s	remaining: 1.19s
# 941:	learn: 3.1548297	total: 19s	remaining: 1.17s
# 942:	learn: 3.1535923	total: 19s	remaining: 1.15s
# 943:	learn: 3.1528419	total: 19s	remaining: 1.13s
# 944:	learn: 3.1520773	total: 19s	remaining: 1.11s
# 945:	learn: 3.1514660	total: 19.1s	remaining: 1.09s
# 946:	learn: 3.1507953	total: 19.1s	remaining: 1.07s
# 947:	learn: 3.1494100	total: 19.1s	remaining: 1.05s
# 948:	learn: 3.1486545	total: 19.1s	remaining: 1.03s
# 949:	learn: 3.1471615	total: 19.1s	remaining: 1.01s
# 950:	learn: 3.1464516	total: 19.2s	remaining: 988ms
# 951:	learn: 3.1450642	total: 19.2s	remaining: 967ms
# 952:	learn: 3.1444027	total: 19.2s	remaining: 947ms
# 953:	learn: 3.1436278	total: 19.2s	remaining: 927ms
# 954:	learn: 3.1428933	total: 19.2s	remaining: 907ms
# 955:	learn: 3.1422404	total: 19.3s	remaining: 887ms
# 956:	learn: 3.1414983	total: 19.3s	remaining: 866ms
# 957:	learn: 3.1409359	total: 19.3s	remaining: 846ms
# 958:	learn: 3.1393198	total: 19.3s	remaining: 826ms
# 959:	learn: 3.1379036	total: 19.3s	remaining: 806ms
# 960:	learn: 3.1358355	total: 19.4s	remaining: 786ms
# 961:	learn: 3.1350835	total: 19.4s	remaining: 766ms
# 962:	learn: 3.1344421	total: 19.4s	remaining: 745ms
# 963:	learn: 3.1338127	total: 19.4s	remaining: 725ms
# 964:	learn: 3.1325066	total: 19.4s	remaining: 705ms
# 965:	learn: 3.1318804	total: 19.5s	remaining: 685ms
# 966:	learn: 3.1313184	total: 19.5s	remaining: 665ms
# 967:	learn: 3.1298346	total: 19.5s	remaining: 644ms
# 968:	learn: 3.1292494	total: 19.5s	remaining: 624ms
# 969:	learn: 3.1269793	total: 19.5s	remaining: 604ms
# 970:	learn: 3.1263736	total: 19.6s	remaining: 584ms
# 971:	learn: 3.1253336	total: 19.6s	remaining: 564ms
# 972:	learn: 3.1247524	total: 19.6s	remaining: 544ms
# 973:	learn: 3.1236592	total: 19.6s	remaining: 524ms
# 974:	learn: 3.1216940	total: 19.6s	remaining: 503ms
# 975:	learn: 3.1202147	total: 19.6s	remaining: 483ms
# 976:	learn: 3.1192030	total: 19.7s	remaining: 463ms
# 977:	learn: 3.1168652	total: 19.7s	remaining: 443ms
# 978:	learn: 3.1155455	total: 19.7s	remaining: 423ms
# 979:	learn: 3.1142392	total: 19.7s	remaining: 403ms
# 980:	learn: 3.1123989	total: 19.7s	remaining: 382ms
# 981:	learn: 3.1096071	total: 19.8s	remaining: 362ms
# 982:	learn: 3.1088510	total: 19.8s	remaining: 342ms
# 983:	learn: 3.1071210	total: 19.8s	remaining: 322ms
# 984:	learn: 3.1063953	total: 19.8s	remaining: 302ms
# 985:	learn: 3.1056633	total: 19.8s	remaining: 282ms
# 986:	learn: 3.1048319	total: 19.9s	remaining: 262ms
# 987:	learn: 3.1039078	total: 19.9s	remaining: 242ms
# 988:	learn: 3.1020947	total: 19.9s	remaining: 221ms
# 989:	learn: 3.1003240	total: 19.9s	remaining: 201ms
# 990:	learn: 3.0996112	total: 20s	remaining: 181ms
# 991:	learn: 3.0990203	total: 20s	remaining: 161ms
# 992:	learn: 3.0960313	total: 20s	remaining: 141ms
# 993:	learn: 3.0926516	total: 20s	remaining: 121ms
# 994:	learn: 3.0911472	total: 20s	remaining: 101ms
# 995:	learn: 3.0900284	total: 20s	remaining: 80.5ms
# 996:	learn: 3.0893017	total: 20.1s	remaining: 60.4ms
# 997:	learn: 3.0880262	total: 20.1s	remaining: 40.3ms
# 998:	learn: 3.0871191	total: 20.1s	remaining: 20.1ms
# 999:	learn: 3.0855789	total: 20.1s	remaining: 0us
# Printing to ./data/submission2.csv

# %% [markdown]
# ## AzureML

# %%
from azureml.core.workspace import Workspace

# %%
# !ls ./AzureML/configuration.yml
# Out:
# Dockerfiles  NBSETUP.md  configuration.ipynb  how-to-use-azureml  tutorials
# LICENSE      README	 configuration.yml    index.md
# Licenses     README.md	 contrib	      setup-environment

# %%
Workspace.create?

# %%
import os
from azureml.core.authentication import ServicePrincipalAuthentication

service_principal_password = os.environ.get("AZUREML_PASSWORD")

# %%
service_principal_password

# %%
ws = Workspace.create(name='hackpromoworkspace',
               subscription_id='5e81e9b4-742a-4c1e-bf1a-93f66c614eaa',
               resource_group='HackPromoLenta',
               create_resource_group=False,
               location='eastus2'
               )
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code C5P2GJ9Z9 to authenticate.
# You have logged in. Now let us find all the subscriptions to which you have access...
# Interactive authentication successfully completed.
# Deploying AppInsights with name hackprominsights9bb3fb2e.
# Deployed AppInsights with name hackprominsights9bb3fb2e. Took 3.86 seconds.
# Deploying StorageAccount with name hackpromstoragec278afdea.
# Deploying KeyVault with name hackpromkeyvault48315c33.
# Deployed KeyVault with name hackpromkeyvault48315c33. Took 19.34 seconds.
# Deployed StorageAccount with name hackpromstoragec278afdea. Took 25.45 seconds.
# Deploying Workspace with name hackpromoworkspace.
# Deployed Workspace with name hackpromoworkspace. Took 27.98 seconds.

# %%
import logging

automl_settings = {
    "iteration_timeout_minutes": 10,
    "experiment_timeout_hours": 0.3,
    "enable_early_stopping": True,
    "primary_metric": 'normalized_mean_absolute_error',
    "featurization": 'auto',
    "verbosity": logging.INFO,
    "n_cross_validations": 5
}

# %%
from azureml.train.automl import AutoMLConfig

automl_config = AutoMLConfig(task='regression',
                             debug_log='automated_ml_errors.log',
                             training_data=X_all,
                             label_column_name="UpLift",
                             **automl_settings)

# %%
from azureml.core.experiment import Experiment

# %%
experiment = Experiment(ws, "uplift-cat-feats-automl")
local_run = experiment.submit(automl_config, show_output=True)
# Out:
# ---------------------------------------------------------------------------
# ValidationException                       Traceback (most recent call last)
# <ipython-input-37-a48ad0d40497> in <module>
#       1 experiment = Experiment(ws, "uplift-cat-feats-automl")
# ----> 2 local_run = experiment.submit(automl_config, show_output=True)
#
# /anaconda/envs/azureml_py36_automl/lib/python3.6/site-packages/azureml/core/experiment.py in submit(self, config, tags, **kwargs)
#     218         submit_func = get_experiment_submit(config)
#     219         with self._log_context("submit config {}".format(config.__class__.__name__)):
# --> 220             run = submit_func(config, self.workspace, self.name, **kwargs)
#     221         if tags is not None:
#     222             run.set_tags(tags)
#
# /anaconda/envs/azureml_py36_automl/lib/python3.6/site-packages/azureml/train/automl/automlconfig.py in _automl_static_submit(automl_config_object, workspace, experiment_name, **kwargs)
#     105             compute_target,
#     106             parent_run_id,
# --> 107             show_output)
#     108
#     109         automl_run.add_properties(global_tracking_info_registry.gather_all(settings.path))
#
# /anaconda/envs/azureml_py36_automl/lib/python3.6/site-packages/azureml/train/automl/automlconfig.py in _start_execution(experiment, settings_obj, fit_params, run_config, compute_target, parent_run_id, show_output)
#     207             package_utilities._get_package_incompatibilities(
#     208                 packages=package_utilities.AUTOML_PACKAGES,
# --> 209                 ignored_dependencies=package_utilities._PACKAGES_TO_IGNORE_VERSIONS
#     210             )
#     211         automl_run = _default_execution(experiment, settings_obj, fit_params, True, show_output, parent_run_id)
#
# /anaconda/envs/azureml_py36_automl/lib/python3.6/site-packages/azureml/automl/core/package_utilities.py in _get_package_incompatibilities(packages, ignored_dependencies, is_databricks_run)
#     428                         missing_packages_message='\n'.join(messages),
#     429                         reference_code=ReferenceCodes._PACKAGE_INCOMPATIBILITIES_FOUND,
# --> 430                         validated_requirements_file_path=VALIDATED_REQ_FILE_PATH
#     431                     )
#     432                 )
#
# ValidationException: ValidationException:
# 	Message: Install the required versions of packages using the requirements file. Requirements file location: /anaconda/envs/azureml_py36_automl/lib/python3.6/site-packages/azureml/automl/core/validated_linux_requirements.txt. Alternatively, use remote target to avoid dependency management.
# Package name/Required version/Installed version
# azureml-train-automl-runtime/pandas<1.0.0,>=0.21.0/pandas 1.1.5
# azureml-train-automl-runtime/jinja2<=2.11.2/Jinja2 2.11.3
# azureml-automl-runtime/pandas<1.0.0,>=0.21.0/pandas 1.1.5
# 	InnerException: None
# 	ErrorResponse
# {
#     "error": {
#         "code": "UserError",
#         "message": "Install the required versions of packages using the requirements file. Requirements file location: /anaconda/envs/azureml_py36_automl/lib/python3.6/site-packages/azureml/automl/core/validated_linux_requirements.txt. Alternatively, use remote target to avoid dependency management. \nPackage name/Required version/Installed version\nazureml-train-automl-runtime/pandas<1.0.0,>=0.21.0/pandas 1.1.5\nazureml-train-automl-runtime/jinja2<=2.11.2/Jinja2 2.11.3\nazureml-automl-runtime/pandas<1.0.0,>=0.21.0/pandas 1.1.5",
#         "target": "azureml-train-automl-runtime,azureml-automl-runtime",
#         "inner_error": {
#             "code": "NotSupported",
#             "inner_error": {
#                 "code": "IncompatibleOrMissingDependency"
#             }
#         },
#         "reference_code": "435ab938-fd87-49bc-932e-6eec0d6aee4f"
#     }
# }
